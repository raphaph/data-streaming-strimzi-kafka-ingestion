# %%
import os
import time
import argparse
import pandas as pd
import numpy as np
from faker import Faker
from sqlalchemy import create_engine
from datetime import datetime
from dotenv import load_dotenv
from faker_vehicle import VehicleProvider

load_dotenv()
# Out:
# True

# %%
username = os.environ.get("POSTGRES_DATABASE_USER")
password = os.environ.get("POSTGRES_PASSWORD")
host = os.environ.get("POSTGRES_HOST")
port = os.environ.get("POSTGRES_PORT")
database = os.environ.get("POSTGRES_DATABASE")
table = os.environ.get("POSTGRES_TABLE")

# %%
# função para parsear a saída do parâmetro SILENT
def str2bool(v):
    if isinstance(v, bool):
       return v
    if v.lower() in ('yes', 'true', 't', 'y', '1'):
        return True
    elif v.lower() in ('no', 'false', 'f', 'n', '0'):
        return False
    else:
        raise argparse.ArgumentTypeError('Boolean value expected.')

# %%
# Instancia a classe Faker
faker = Faker()
faker.add_provider(VehicleProvider)

if __name__ == "__main__":

    parser = argparse.ArgumentParser(description='Generate fake data...')

    parser.add_argument('--interval', type=int, default=1,
                        help='interval of generating fake data in seconds')
    parser.add_argument('-n', type=int, default=1,
                        help='sample size')
    parser.add_argument('--connection-string', '-cs', dest="connection_string", 
                        type=str, default=f'postgresql://{username}:{password}@{host}:{port}/{database}',
                        help='Connection string to the database')
    parser.add_argument('--silent', type=str2bool, nargs='?',
                        const=True, default=False,
                        help="print fake data")

    args, unknown = parser.parse_known_args()

    print(f"Args parsed:")
    print(f"Interval: {args.interval}")
    print(f"Sample size; {args.n}")
    print(f"Connection string: {args.connection_string}", end='\n\n')

    #-----------------------------------------------------------------

    engine = create_engine(args.connection_string)

    print("Iniciando a simulacao...", end="\n\n")

    # Gera dados fake a faz ingestão
    while True:
        customer_id   = [faker.random_int() for i in range(args.n)]
        ano_modelo        = [faker.vehicle_year_make_model() for i in range(args.n)]
        modelo             = [faker.vehicle_make_model() for i in range(args.n)]
        fabricante             = [faker.vehicle_make() for i in range(args.n)]
        ano_veiculo     = [faker.vehicle_year() for i in range(args.n)]
        categoria  = [faker.vehicle_category() for i in range(args.n)]
        dt_update         = [datetime.now() for i in range(args.n)]

        df = pd.DataFrame({
            "customer_id": customer_id,
            "ano_modelo": ano_modelo,
            "modelo": modelo,
            "fabricante": fabricante,
            "ano_veiculo": ano_veiculo,
            "categoria": categoria,
            "dt_update": dt_update,
        })

        df.to_sql("vehicle", con=engine, if_exists="append", index=False)

        if not args.silent:
            print(df, end="\n\n")

        time.sleep(args.interval)
# Out:
# Args parsed:
# Interval: 0.005
# Sample size; 1
# Connection string: postgresql://postgres:mantis0090a@localhost:5432/postgres
#
# Iniciando a simulacao...
#
#    customer_id                  ano_modelo              modelo fabricante  \
# 0         8994  2017 Mercedes-Benz G-Class  Pontiac Grand Prix     Nissan
#
#   ano_veiculo categoria                  dt_update
# 0        2015       SUV 2024-08-18 13:36:50.601287
#
#    customer_id                     ano_modelo                  modelo  \
# 0         5642  2015 Nissan Frontier King Cab  Cadillac Sixty Special
#
#   fabricante ano_veiculo categoria                  dt_update
# 0      Lexus        2018     Sedan 2024-08-18 13:36:50.672878
#
#    customer_id           ano_modelo                  modelo fabricante  \
# 0         7773  2002 Toyota 4Runner  Mercedes-Benz SL-Class        GMC
#
#   ano_veiculo categoria                  dt_update
# 0        1998    Pickup 2024-08-18 13:36:50.693265
#
#    customer_id     ano_modelo                 modelo fabricante ano_veiculo  \
# 0         6367  2013 Lexus GS  Dodge Dakota Club Cab        GMC        1992
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:50.713286
#
#    customer_id      ano_modelo         modelo fabricante ano_veiculo  \
# 0         7405  2015 Ford Edge  Dodge Avenger  Chevrolet        2012
#
#   categoria                  dt_update
# 0     Sedan 2024-08-18 13:36:50.733802
#
#    customer_id                 ano_modelo                   modelo  \
# 0         1497  2019 Ford Transit 250 Van  Dodge Ram 3500 Quad Cab
#
#     fabricante ano_veiculo categoria                  dt_update
# 0  Lamborghini        2019       SUV 2024-08-18 13:36:50.753813
#
#    customer_id                                    ano_modelo  \
# 0         7110  2010 Chevrolet Silverado 3500 HD Regular Cab
#
#                modelo fabricante ano_veiculo categoria  \
# 0  Nissan Regular Cab   INFINITI        1992    Pickup
#
#                    dt_update
# 0 2024-08-18 13:36:50.772738
#
#    customer_id        ano_modelo    modelo fabricante ano_veiculo categoria  \
# 0          177  2003 Isuzu Axiom  Lexus IS        GMC        2002       SUV
#
#                    dt_update
# 0 2024-08-18 13:36:50.792382
#
#    customer_id        ano_modelo             modelo fabricante ano_veiculo  \
# 0         5571  2019 Honda Civic  Lincoln Navigator     Nissan        2014
#
#      categoria                  dt_update
# 0  Convertible 2024-08-18 13:36:50.812406
#
#    customer_id                  ano_modelo       modelo fabricante  \
# 0         6181  2007 Chevrolet Monte Carlo  Buick Regal      Buick
#
#   ano_veiculo categoria                  dt_update
# 0        2008       SUV 2024-08-18 13:36:50.830919
#
#    customer_id                    ano_modelo         modelo fabricante  \
# 0         9657  2004 Ford Freestar Passenger  Honda Odyssey       Saab
#
#   ano_veiculo categoria                  dt_update
# 0        2006     Sedan 2024-08-18 13:36:50.848437
#
#    customer_id     ano_modelo                  modelo fabricante ano_veiculo  \
# 0          105  2013 Scion iQ  Mercedes-Benz SL-Class      Dodge        2002
#
#    categoria                  dt_update
# 0  Hatchback 2024-08-18 13:36:50.866447
#
#    customer_id       ano_modelo          modelo fabricante ano_veiculo  \
# 0         5256  2016 MAZDA CX-3  Mercury Tracer        BMW        1993
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:50.885180
#
#    customer_id        ano_modelo                modelo fabricante ano_veiculo  \
# 0         5281  2001 Toyota RAV4  GMC 1500 Regular Cab        BMW        2020
#
#      categoria                  dt_update
# 0  Convertible 2024-08-18 13:36:50.904014
#
#    customer_id                       ano_modelo        modelo fabricante  \
# 0         2098  1996 Chevrolet 2500 Regular Cab  MAZDA MAZDA6     Nissan
#
#   ano_veiculo categoria                  dt_update
# 0        2001       SUV 2024-08-18 13:36:50.922034
#
#    customer_id             ano_modelo         modelo fabricante ano_veiculo  \
# 0          267  1997 Chrysler Sebring  Toyota Avalon  Chevrolet        2003
#
#             categoria                  dt_update
# 0  Coupe, Convertible 2024-08-18 13:36:50.940290
#
#    customer_id            ano_modelo       modelo fabricante ano_veiculo  \
# 0         8792  1998 Chevrolet Metro  Buick Regal     Toyota        2001
#
#   categoria                  dt_update
# 0     Wagon 2024-08-18 13:36:50.958165
#
#    customer_id          ano_modelo         modelo fabricante ano_veiculo  \
# 0         9179  2013 Dodge Avenger  MAZDA Protege      Dodge        1998
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:50.976685
#
#    customer_id                  ano_modelo         modelo     fabricante  \
# 0         4440  1994 Mercedes-Benz C-Class  Jaguar I-PACE  Mercedes-Benz
#
#   ano_veiculo categoria                  dt_update
# 0        2018    Pickup 2024-08-18 13:36:50.994878
#
#    customer_id         ano_modelo             modelo fabricante ano_veiculo  \
# 0         6247  2012 Cadillac SRX  Mercedes-Benz GLE  Chevrolet        1996
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:51.013095
#
#    customer_id                   ano_modelo                   modelo  \
# 0         4375  2005 Mercedes-Benz SL-Class  Dodge Ram 2500 Mega Cab
#
#   fabricante ano_veiculo categoria                  dt_update
# 0      Dodge        2003       SUV 2024-08-18 13:36:51.031129
#
#    customer_id       ano_modelo                       modelo fabricante  \
# 0         5786  2016 MAZDA CX-9  GMC Sierra 2500 Regular Cab      Acura
#
#   ano_veiculo categoria                  dt_update
# 0        2015    Pickup 2024-08-18 13:36:51.050648
#
#    customer_id           ano_modelo                    modelo fabricante  \
# 0         6621  1998 Oldsmobile LSS  Chrysler Pacifica Hybrid      Acura
#
#   ano_veiculo categoria                  dt_update
# 0        2003    Pickup 2024-08-18 13:36:51.070337
#
#    customer_id     ano_modelo               modelo fabricante ano_veiculo  \
# 0         8797  1999 Acura TL  Ford F150 Super Cab  Chevrolet        2009
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:51.091859
#
#    customer_id                  ano_modelo                            modelo  \
# 0         4821  2002 Ford Ranger Super Cab  Chevrolet Express 2500 Passenger
#
#   fabricante ano_veiculo  categoria                  dt_update
# 0    Porsche        2003  Hatchback 2024-08-18 13:36:51.110373
#
#    customer_id               ano_modelo             modelo fabricante  \
# 0         3732  1994 Pontiac Grand Prix  Toyota Highlander    Porsche
#
#   ano_veiculo categoria                  dt_update
# 0        2002       SUV 2024-08-18 13:36:51.128396
#
#    customer_id          ano_modelo             modelo fabricante ano_veiculo  \
# 0          111  2012 Hyundai Azera  Alfa Romeo Spider      Buick        2012
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:51.147915
#
#    customer_id       ano_modelo                   modelo fabricante  \
# 0         4837  2020 Subaru WRX  Kia Niro Plug-in Hybrid        BMW
#
#   ano_veiculo     categoria                  dt_update
# 0        2005  Sedan, Wagon 2024-08-18 13:36:51.167434
#
#    customer_id             ano_modelo      modelo fabricante ano_veiculo  \
# 0         7269  2001 Lincoln Town Car  Kia Sedona     Jaguar        2013
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:51.187442
#
#    customer_id      ano_modelo        modelo fabricante ano_veiculo categoria  \
# 0         7667  2014 Acura ILX  Toyota Supra      MAZDA        2008     Coupe
#
#                    dt_update
# 0 2024-08-18 13:36:51.206466
#
#    customer_id                     ano_modelo        modelo fabricante  \
# 0         6385  2005 GMC Sierra 1500 Crew Cab  Nissan Quest  Chevrolet
#
#   ano_veiculo    categoria                  dt_update
# 0        2009  Van/Minivan 2024-08-18 13:36:51.225479
#
#    customer_id                 ano_modelo                 modelo fabricante  \
# 0         2002  1996 GMC 2500 Regular Cab  Mercedes-Benz M-Class        GMC
#
#   ano_veiculo               categoria               dt_update
# 0        2000  Hatchback, Convertible 2024-08-18 13:36:51.245
#
#    customer_id       ano_modelo      modelo fabricante ano_veiculo  \
# 0         6600  2009 Honda CR-V  Lincoln LS     Nissan        2016
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:51.264521
#
#    customer_id      ano_modelo       modelo     fabricante ano_veiculo  \
# 0         7946  2017 Acura NSX  Geo Tracker  Mercedes-Benz        2006
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:51.283043
#
#    customer_id     ano_modelo                 modelo fabricante ano_veiculo  \
# 0         2736  2011 Lexus ES  GMC Savana 1500 Cargo       Jeep        1999
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:51.301557
#
#    customer_id                     ano_modelo            modelo fabricante  \
# 0         9083  2014 Toyota Tacoma Double Cab  MAZDA MX-5 Miata     Nissan
#
#   ano_veiculo           categoria                  dt_update
# 0        1994  Convertible, Coupe 2024-08-18 13:36:51.319069
#
#    customer_id                       ano_modelo    modelo fabricante  \
# 0         6186  2019 Ford Transit Connect Cargo  Lexus SC      MAZDA
#
#   ano_veiculo    categoria                  dt_update
# 0        2003  Van/Minivan 2024-08-18 13:36:51.336587
#
#    customer_id            ano_modelo          modelo fabricante ano_veiculo  \
# 0         4011  1995 Hyundai Elantra  Hyundai Sonata    Porsche        1996
#
#   categoria                  dt_update
# 0     Sedan 2024-08-18 13:36:51.354597
#
#    customer_id               ano_modelo               modelo fabricante  \
# 0         3175  1997 Dodge Ram Van 2500  Ford F250 Super Cab       Ford
#
#   ano_veiculo categoria                  dt_update
# 0        2010     Sedan 2024-08-18 13:36:51.372101
#
#    customer_id          ano_modelo             modelo     fabricante  \
# 0         2116  2001 Nissan Altima  Mitsubishi Mirage  Mercedes-Benz
#
#   ano_veiculo categoria                  dt_update
# 0        2004       SUV 2024-08-18 13:36:51.390132
#
#    customer_id                   ano_modelo         modelo  fabricante  \
# 0         8964  2003 GMC Sonoma Regular Cab  Jeep Wrangler  Mitsubishi
#
#   ano_veiculo categoria                  dt_update
# 0        1992       SUV 2024-08-18 13:36:51.407647
#
#    customer_id                ano_modelo             modelo     fabricante  \
# 0         5365  1993 Mercedes-Benz 500 E  Nissan Pathfinder  Mercedes-Benz
#
#   ano_veiculo categoria                  dt_update
# 0        2013       SUV 2024-08-18 13:36:51.425654
#
#    customer_id        ano_modelo      modelo fabricante ano_veiculo categoria  \
# 0           30  2006 Honda Pilot  INFINITI I        GMC        2015    Pickup
#
#                    dt_update
# 0 2024-08-18 13:36:51.443055
#
#    customer_id       ano_modelo  modelo fabricante ano_veiculo  categoria  \
# 0         5831  2019 Volvo XC60  BMW X5     Toyota        2016  Hatchback
#
#                    dt_update
# 0 2024-08-18 13:36:51.460688
#
#    customer_id                  ano_modelo                 modelo fabricante  \
# 0         1844  2020 Toyota Tundra CrewMax  Ford Ranger Super Cab      MAZDA
#
#   ano_veiculo categoria                  dt_update
# 0        2013       SUV 2024-08-18 13:36:51.477929
#
#    customer_id                  ano_modelo                    modelo  \
# 0         2566  1992 Mercury Grand Marquis  GMC Sierra 1500 Crew Cab
#
#   fabricante ano_veiculo categoria                  dt_update
# 0  Chevrolet        2012       SUV 2024-08-18 13:36:51.497444
#
#    customer_id      ano_modelo                     modelo fabricante  \
# 0         8203  2014 Acura MDX  Dodge Sprinter 2500 Cargo       Audi
#
#   ano_veiculo categoria                  dt_update
# 0        2017     Sedan 2024-08-18 13:36:51.516301
#
#    customer_id            ano_modelo        modelo fabricante ano_veiculo  \
# 0         3228  2003 Hyundai Tiburon  Ford Contour     Toyota        2013
#
#   categoria                  dt_update
# 0     Sedan 2024-08-18 13:36:51.536338
#
#    customer_id             ano_modelo                modelo fabricante  \
# 0          419  2002 MAZDA MX-5 Miata  Mitsubishi Outlander        Ram
#
#   ano_veiculo categoria                  dt_update
# 0        2019       SUV 2024-08-18 13:36:51.555212
#
#    customer_id      ano_modelo         modelo     fabricante ano_veiculo  \
# 0          656  2019 Acura RLX  Jeep Cherokee  Mercedes-Benz        2012
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:51.574725
#
#    customer_id            ano_modelo  modelo fabricante ano_veiculo  \
# 0         6304  2020 Lincoln Aviator  BMW X5        GMC        1992
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:51.593766
#
#    customer_id                          ano_modelo        modelo fabricante  \
# 0         1944  2017 GMC Sierra 3500 HD Double Cab  Suzuki Swift     Jaguar
#
#   ano_veiculo           categoria                  dt_update
# 0        2020  Coupe, Convertible 2024-08-18 13:36:51.614778
#
#    customer_id              ano_modelo         modelo fabricante ano_veiculo  \
# 0         8420  2011 Volkswagen Tiguan  Nissan Sentra     Toyota        1993
#
#   categoria                  dt_update
# 0     Coupe 2024-08-18 13:36:51.634298
#
#    customer_id     ano_modelo                        modelo fabricante  \
# 0         3811  2016 BMW X6 M  GMC Sierra 3500 Extended Cab    Porsche
#
#   ano_veiculo categoria                  dt_update
# 0        2001       SUV 2024-08-18 13:36:51.654328
#
#    customer_id      ano_modelo    modelo fabricante ano_veiculo    categoria  \
# 0         9656  2004 Jaguar XJ  Lexus LS      Dodge        1995  Convertible
#
#                    dt_update
# 0 2024-08-18 13:36:51.674046
#
#    customer_id       ano_modelo        modelo fabricante ano_veiculo  \
# 0         1762  2012 Maybach 57  Eagle Summit      Dodge        2015
#
#             categoria                  dt_update
# 0  Coupe, Convertible 2024-08-18 13:36:51.695434
#
#    customer_id                   ano_modelo         modelo fabricante  \
# 0         8596  2015 Mercedes-Benz GL-Class  Tesla Model X       Ford
#
#   ano_veiculo    categoria                  dt_update
# 0        2013  Van/Minivan 2024-08-18 13:36:51.715450
#
#    customer_id                  ano_modelo         modelo fabricante  \
# 0         3193  1997 Mercedes-Benz S-Class  Oldsmobile 88  Chevrolet
#
#   ano_veiculo     categoria                  dt_update
# 0        2011  Sedan, Wagon 2024-08-18 13:36:51.735195
#
#    customer_id       ano_modelo        modelo fabricante ano_veiculo  \
# 0         2562  2004 INFINITI I  smart fortwo     Toyota        2005
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:51.753712
#
#    customer_id                     ano_modelo        modelo fabricante  \
# 0         3707  2005 Nissan Frontier King Cab  Nissan Versa       Ford
#
#   ano_veiculo    categoria                  dt_update
# 0        2017  Van/Minivan 2024-08-18 13:36:51.772723
#
#    customer_id                       ano_modelo             modelo  \
# 0          730  2016 Mitsubishi Outlander Sport  Lincoln Navigator
#
#       fabricante ano_veiculo categoria                  dt_update
# 0  Mercedes-Benz        2003     Wagon 2024-08-18 13:36:51.791191
#
#    customer_id             ano_modelo     modelo fabricante ano_veiculo  \
# 0         7690  2008 Volkswagen Jetta  Volvo V70        GMC        2004
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:51.813202
#
#    customer_id         ano_modelo                   modelo fabricante  \
# 0         2590  2014 Cadillac XTS  Chrysler Town & Country       Ford
#
#   ano_veiculo categoria                  dt_update
# 0        2011    Pickup 2024-08-18 13:36:51.833018
#
#    customer_id             ano_modelo              modelo fabricante  \
# 0         7046  2006 Buick Rendezvous  Chevrolet Corvette    Ferrari
#
#   ano_veiculo categoria                  dt_update
# 0        1992       SUV 2024-08-18 13:36:51.851026
#
#    customer_id            ano_modelo         modelo fabricante ano_veiculo  \
# 0         4775  2001 Volkswagen Golf  Pontiac Aztek        GMC        2004
#
#      categoria                  dt_update
# 0  Convertible 2024-08-18 13:36:51.869051
#
#    customer_id                                         ano_modelo  \
# 0         7417  2007 Chevrolet Silverado (Classic) 3500 Extend...
#
#                           modelo fabricante ano_veiculo  \
# 0  Dodge Grand Caravan Passenger       Ford        2016
#
#                           categoria                  dt_update
# 0  Sedan, Coupe, Convertible, Wagon 2024-08-18 13:36:51.887167
#
#    customer_id                       ano_modelo       modelo fabricante  \
# 0         2678  2014 Ford Transit Connect Cargo  Ford Escort      Lexus
#
#   ano_veiculo categoria                  dt_update
# 0        2005    Pickup 2024-08-18 13:36:51.904689
#
#    customer_id         ano_modelo        modelo fabricante ano_veiculo  \
# 0         1777  2011 MINI Clubman  Ford Mustang     Toyota        2018
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:51.922201
#
#    customer_id               ano_modelo        modelo fabricante ano_veiculo  \
# 0         1869  2007 Mitsubishi Eclipse  BMW 6 Series      Honda        2008
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:51.939725
#
#    customer_id              ano_modelo  modelo fabricante ano_veiculo  \
# 0          204  2002 Cadillac Escalade  BMW X7        GMC        2006
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:51.958244
#
#    customer_id     ano_modelo     modelo fabricante ano_veiculo  \
# 0          492  2015 Kia Soul  Saab 9000        Kia        2009
#
#              categoria                  dt_update
# 0  Wagon, Sedan, Coupe 2024-08-18 13:36:51.975760
#
#    customer_id      ano_modelo   modelo fabricante ano_veiculo    categoria  \
# 0         4835  2014 Ford Edge  Audi A8    Mercury        1997  Van/Minivan
#
#                    dt_update
# 0 2024-08-18 13:36:51.993771
#
#    customer_id                ano_modelo                             modelo  \
# 0          151  1992 Mercedes-Benz 400 E  Chevrolet Silverado 1500 Crew Cab
#
#   fabricante ano_veiculo categoria                  dt_update
# 0       Ford        2007     Sedan 2024-08-18 13:36:52.012648
#
#    customer_id               ano_modelo     modelo fabricante ano_veiculo  \
# 0         1631  1999 Chevrolet Cavalier  Jaguar XK    Bentley        2016
#
#   categoria                  dt_update
# 0     Sedan 2024-08-18 13:36:52.029755
#
#    customer_id               ano_modelo              modelo  fabricante  \
# 0         2661  2018 Chevrolet Corvette  Pontiac Grand Prix  Mitsubishi
#
#   ano_veiculo  categoria                  dt_update
# 0        2011  Hatchback 2024-08-18 13:36:52.047280
#
#    customer_id                      ano_modelo                        modelo  \
# 0         5546  2013 Toyota Tacoma Regular Cab  Land Rover Range Rover Sport
#
#   fabricante ano_veiculo categoria                  dt_update
# 0  Chevrolet        2012     Sedan 2024-08-18 13:36:52.064798
#
#    customer_id         ano_modelo    modelo fabricante ano_veiculo  \
# 0         3429  2016 GMC Yukon XL  Lexus LX        GMC        2012
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:52.084503
#
#    customer_id                                    ano_modelo  \
# 0          873  2007 Chevrolet Silverado 2500 HD Regular Cab
#
#                       modelo fabricante ano_veiculo categoria  \
# 0  Chevrolet Suburban 3500HD       MINI        2000    Pickup
#
#                    dt_update
# 0 2024-08-18 13:36:52.102020
#
#    customer_id                  ano_modelo         modelo fabricante  \
# 0         6635  2007 Dodge Dakota Club Cab  Lotus Exige S      Volvo
#
#   ano_veiculo    categoria                  dt_update
# 0        1997  Van/Minivan 2024-08-18 13:36:52.121043
#
#    customer_id                              ano_modelo             modelo  \
# 0         1225  2009 Chevrolet Silverado 1500 Crew Cab  Ram 3500 Crew Cab
#
#   fabricante ano_veiculo categoria                  dt_update
# 0    Porsche        2008    Pickup 2024-08-18 13:36:52.139556
#
#    customer_id   ano_modelo                   modelo fabricante ano_veiculo  \
# 0         8682  2009 BMW X3  GMC 2500 HD Regular Cab       Audi        2005
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:52.158069
#
#    customer_id                         ano_modelo            modelo  \
# 0         7119  2019 Hyundai Ioniq Plug-in Hybrid  Porsche Panamera
#
#   fabricante ano_veiculo categoria                  dt_update
# 0   Cadillac        1999     Coupe 2024-08-18 13:36:52.176076
#
#    customer_id                         ano_modelo          modelo fabricante  \
# 0         9688  2011 Chevrolet Express 2500 Cargo  Chevrolet Volt      Dodge
#
#   ano_veiculo categoria                  dt_update
# 0        2012     Sedan 2024-08-18 13:36:52.194097
#
#    customer_id                   ano_modelo               modelo fabricante  \
# 0         2066  1993 Chevrolet Sportvan G20  MAZDA MX-5 Miata RF       Ford
#
#   ano_veiculo           categoria                  dt_update
# 0        2014  Sedan, Convertible 2024-08-18 13:36:52.211913
#
#    customer_id   ano_modelo                      modelo fabricante  \
# 0         1960  2018 BMW X2  Chevrolet 3500 Regular Cab        GMC
#
#   ano_veiculo categoria                  dt_update
# 0        2019    Pickup 2024-08-18 13:36:52.230431
#
#    customer_id         ano_modelo                     modelo  fabricante  \
# 0         8258  2005 MAZDA MAZDA6  Toyota Tacoma Regular Cab  Mitsubishi
#
#   ano_veiculo categoria                  dt_update
# 0        1996    Pickup 2024-08-18 13:36:52.248463
#
#    customer_id              ano_modelo                modelo  fabricante  \
# 0         1671  2001 Cadillac Eldorado  GMC Rally Wagon 1500  Land Rover
#
#   ano_veiculo categoria                  dt_update
# 0        2014       SUV 2024-08-18 13:36:52.267470
#
#    customer_id          ano_modelo         modelo fabricante ano_veiculo  \
# 0         5682  2006 Jaguar S-Type  Nissan Sentra     Nissan        2015
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:52.285992
#
#    customer_id                ano_modelo       modelo fabricante ano_veiculo  \
# 0         7944  2012 Ford F150 Super Cab  Buick Regal  Chevrolet        2013
#
#   categoria                  dt_update
# 0     Coupe 2024-08-18 13:36:52.306164
#
#    customer_id                  ano_modelo                         modelo  \
# 0         6288  2013 Toyota Tundra CrewMax  Dodge Grand Caravan Passenger
#
#   fabricante ano_veiculo categoria                  dt_update
# 0     Subaru        2004     Sedan 2024-08-18 13:36:52.326726
#
#    customer_id                  ano_modelo       modelo fabricante  \
# 0          899  1996 Ford F350 Regular Cab  Genesis G90       Ford
#
#   ano_veiculo  categoria                  dt_update
# 0        2016  Hatchback 2024-08-18 13:36:52.346244
#
#    customer_id                           ano_modelo         modelo fabricante  \
# 0         2934  2018 GMC Sierra 2500 HD Regular Cab  Jeep Wrangler     Suzuki
#
#   ano_veiculo           categoria                  dt_update
# 0        2005  Convertible, Coupe 2024-08-18 13:36:52.367026
#
#    customer_id                    ano_modelo              modelo fabricante  \
# 0         2665  1997 Dodge Ram 3500 Club Cab  Ferrari 458 Italia   Cadillac
#
#   ano_veiculo categoria                  dt_update
# 0        1999     Coupe 2024-08-18 13:36:52.386540
#
#    customer_id          ano_modelo       modelo     fabricante ano_veiculo  \
# 0         1811  2004 Ford Explorer  Subaru Baja  Mercedes-Benz        2010
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:52.404560
#
#    customer_id    ano_modelo     modelo  fabricante ano_veiculo categoria  \
# 0         4384  2014 Audi A8  Acura TSX  Mitsubishi        2006       SUV
#
#                    dt_update
# 0 2024-08-18 13:36:52.423587
#
#    customer_id            ano_modelo    modelo fabricante ano_veiculo  \
# 0         1482  2016 Hyundai Elantra  BMW X5 M  Chevrolet        2004
#
#   categoria                  dt_update
# 0     Coupe 2024-08-18 13:36:52.444098
#
#    customer_id     ano_modelo             modelo fabricante ano_veiculo  \
# 0         2786  2014 Lexus CT  GMC Suburban 1500      Dodge        1992
#
#   categoria                  dt_update
# 0     Coupe 2024-08-18 13:36:52.464106
#
#    customer_id                        ano_modelo                 modelo  \
# 0         4702  1997 Chevrolet 2500 Extended Cab  Mercedes-Benz S-Class
#
#   fabricante ano_veiculo categoria                  dt_update
# 0      Volvo        2014    Pickup 2024-08-18 13:36:52.484123
#
#    customer_id    ano_modelo          modelo fabricante ano_veiculo categoria  \
# 0         7912  2011 Audi S5  Subaru Outback     Toyota        2007    Pickup
#
#                    dt_update
# 0 2024-08-18 13:36:52.503772
#
#    customer_id        ano_modelo                 modelo fabricante  \
# 0         3774  1994 Porsche 928  Mercury Grand Marquis    Porsche
#
#   ano_veiculo categoria                  dt_update
# 0        2011    Pickup 2024-08-18 13:36:52.522294
#
#    customer_id                       ano_modelo            modelo fabricante  \
# 0         9019  1994 Chevrolet 3500 Regular Cab  Mercury Villager  Chevrolet
#
#   ano_veiculo categoria                  dt_update
# 0        2006    Pickup 2024-08-18 13:36:52.539574
#
#    customer_id               ano_modelo     modelo  fabricante ano_veiculo  \
# 0         9485  2004 Pontiac Grand Prix  Jaguar XK  Oldsmobile        2004
#
#    categoria                  dt_update
# 0  Hatchback 2024-08-18 13:36:52.557596
#
#    customer_id                       ano_modelo              modelo  \
# 0         7810  2013 Mitsubishi Outlander Sport  Oldsmobile Bravada
#
#   fabricante ano_veiculo categoria                  dt_update
# 0  Chevrolet        2005       SUV 2024-08-18 13:36:52.575440
#
#    customer_id                                 ano_modelo  \
# 0         5466  2001 Chevrolet Silverado 2500 Regular Cab
#
#                              modelo fabricante ano_veiculo categoria  \
# 0  Chevrolet Express 3500 Passenger    Porsche        1992     Sedan
#
#                    dt_update
# 0 2024-08-18 13:36:52.593463
#
#    customer_id       ano_modelo      modelo fabricante ano_veiculo  \
# 0         1405  1995 Kia Sephia  GMC Acadia        Kia        2019
#
#       categoria                  dt_update
# 0  Sedan, Coupe 2024-08-18 13:36:52.612475
#
#    customer_id      ano_modelo                   modelo fabricante  \
# 0         9214  2009 Jaguar XJ  Dodge Ram 1500 Quad Cab   Maserati
#
#   ano_veiculo categoria                  dt_update
# 0        1995       SUV 2024-08-18 13:36:52.630998
#
#    customer_id              ano_modelo                       modelo  \
# 0         1833  2007 Chrysler Pacifica  smart fortwo electric drive
#
#   fabricante ano_veiculo categoria                  dt_update
# 0       Ford        2014       SUV 2024-08-18 13:36:52.649516
#
#    customer_id           ano_modelo                modelo fabricante  \
# 0         8721  2013 Subaru Impreza  Dodge Ram Wagon 1500    Ferrari
#
#   ano_veiculo categoria                  dt_update
# 0        2006    Pickup 2024-08-18 13:36:52.667548
#
#    customer_id         ano_modelo              modelo fabricante ano_veiculo  \
# 0         3499  1993 MAZDA Navajo  Dodge Ram Van B150  Chevrolet        1999
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:52.686555
#
#    customer_id       ano_modelo                 modelo fabricante ano_veiculo  \
# 0         6657  2018 Subaru WRX  GMC Savana 3500 Cargo   Cadillac        2003
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:52.705221
#
#    customer_id          ano_modelo    modelo fabricante ano_veiculo  \
# 0         3096  2008 Toyota Matrix  Kia Soul     Nissan        1998
#
#    categoria                  dt_update
# 0  Hatchback 2024-08-18 13:36:52.723744
#
#    customer_id                ano_modelo    modelo fabricante ano_veiculo  \
# 0         3649  2003 Jeep Grand Cherokee  Acura TL     Toyota        2006
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:52.741750
#
#    customer_id                   ano_modelo                     modelo  \
# 0         1180  2004 Mercedes-Benz SL-Class  Dodge Sprinter 3500 Cargo
#
#   fabricante ano_veiculo categoria                  dt_update
# 0        GMC        2011    Pickup 2024-08-18 13:36:52.759266
#
#    customer_id    ano_modelo            modelo fabricante ano_veiculo  \
# 0         9314  2018 Audi A7  Mercury Villager        GMC        2012
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:52.778297
#
#    customer_id      ano_modelo                     modelo fabricante  \
# 0         2395  2016 Jaguar XF  GMC Savana 1500 Passenger      MAZDA
#
#   ano_veiculo categoria                  dt_update
# 0        2002    Pickup 2024-08-18 13:36:52.797306
#
#    customer_id                     ano_modelo       modelo fabricante  \
# 0         6885  1997 Mitsubishi Montero Sport  Ford Escape     HUMMER
#
#   ano_veiculo    categoria                  dt_update
# 0        2016  Van/Minivan 2024-08-18 13:36:52.814825
#
#    customer_id    ano_modelo                    modelo fabricante ano_veiculo  \
# 0          503  2006 Audi A8  Isuzu i-280 Extended Cab  Chevrolet        2010
#
#   categoria                  dt_update
# 0     Sedan 2024-08-18 13:36:52.834349
#
#    customer_id            ano_modelo      modelo fabricante ano_veiculo  \
# 0         5768  1999 Pontiac Montana  Saturn VUE  Chevrolet        2015
#
#                 categoria                  dt_update
# 0  Hatchback, Convertible 2024-08-18 13:36:52.851619
#
#    customer_id       ano_modelo             modelo fabricante ano_veiculo  \
# 0         7689  2013 Suzuki SX4  Ram 2500 Crew Cab        Kia        2011
#
#    categoria                  dt_update
# 0  Hatchback 2024-08-18 13:36:52.869147
#
#    customer_id                   ano_modelo    modelo fabricante ano_veiculo  \
# 0         4048  2015 Land Rover Range Rover  Lexus LX  Chevrolet        2005
#
#           categoria                  dt_update
# 0  Sedan, Hatchback 2024-08-18 13:36:52.886829
#
#    customer_id     ano_modelo                   modelo fabricante ano_veiculo  \
# 0         1062  2002 Acura RL  Chrysler Town & Country    Lincoln        2013
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:52.904441
#
#    customer_id                 ano_modelo                     modelo  \
# 0         7180  1994 GMC 1500 Regular Cab  GMC Savana 3500 Passenger
#
#   fabricante ano_veiculo     categoria                  dt_update
# 0       Jeep        2004  Wagon, Sedan 2024-08-18 13:36:52.922459
#
#    customer_id           ano_modelo            modelo fabricante ano_veiculo  \
# 0         9519  2009 Chevrolet Aveo  Chevrolet Blazer    Mercury        2000
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:52.940465
#
#    customer_id                ano_modelo        modelo fabricante ano_veiculo  \
# 0         6351  1994 Toyota Land Cruiser  GMC Envoy XL  Chevrolet        2013
#
#           categoria                  dt_update
# 0  Sedan, Hatchback 2024-08-18 13:36:52.957978
#
#    customer_id            ano_modelo               modelo fabricante  \
# 0         1479  2020 Toyota GR Supra  Jeep Grand Cherokee        GMC
#
#   ano_veiculo categoria                  dt_update
# 0        2018    Pickup 2024-08-18 13:36:52.975500
#
#    customer_id            ano_modelo      modelo fabricante ano_veiculo  \
# 0         8291  2014 Ford Expedition  INFINITI G      MAZDA        2018
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:52.994025
#
#    customer_id         ano_modelo                       modelo  fabricante  \
# 0         9729  2009 Ford Mustang  GMC Sierra 2500 Regular Cab  Volkswagen
#
#   ano_veiculo categoria                  dt_update
# 0        2020     Coupe 2024-08-18 13:36:53.011064
#
#    customer_id                ano_modelo                   modelo fabricante  \
# 0         4445  2018 Nissan NV1500 Cargo  Ford Ranger Regular Cab        GMC
#
#   ano_veiculo categoria                  dt_update
# 0        2004    Pickup 2024-08-18 13:36:53.029090
#
#    customer_id         ano_modelo       modelo fabricante ano_veiculo  \
# 0         4520  2016 Chevrolet SS  Honda Civic       Ford        2004
#
#       categoria                  dt_update
# 0  Sedan, Wagon 2024-08-18 13:36:53.047098
#
#    customer_id                      ano_modelo  \
# 0         7641  1998 GMC Sonoma Club Coupe Cab
#
#                                modelo fabricante ano_veiculo     categoria  \
# 0  Mercedes-Benz Mercedes-AMG S-Class        GMC        2014  Sedan, Wagon
#
#                    dt_update
# 0 2024-08-18 13:36:53.064621
#
#    customer_id     ano_modelo       modelo fabricante ano_veiculo categoria  \
# 0         3544  2001 Lexus GS  Ford Taurus      Acura        2014    Pickup
#
#                    dt_update
# 0 2024-08-18 13:36:53.082134
#
#    customer_id                ano_modelo  \
# 0         7854  2018 MINI Hardtop 4 Door
#
#                                  modelo fabricante ano_veiculo categoria  \
# 0  Ford Econoline E350 Super Duty Cargo  Chevrolet        2018     Sedan
#
#                    dt_update
# 0 2024-08-18 13:36:53.099851
#
#    customer_id           ano_modelo                     modelo     fabricante  \
# 0         7120  1996 Dodge Intrepid  Chevrolet Caprice Classic  Mercedes-Benz
#
#   ano_veiculo categoria                  dt_update
# 0        2002     Sedan 2024-08-18 13:36:53.118363
#
#    customer_id                ano_modelo                       modelo  \
# 0         2045  2013 Toyota Land Cruiser  GMC Sierra 3500 HD Crew Cab
#
#   fabricante ano_veiculo     categoria                  dt_update
# 0       Audi        2004  Sedan, Coupe 2024-08-18 13:36:53.137046
#
#    customer_id          ano_modelo            modelo fabricante ano_veiculo  \
# 0         3128  2017 Toyota Sienna  Volkswagen Atlas      MAZDA        1992
#
#       categoria                  dt_update
# 0  Sedan, Wagon 2024-08-18 13:36:53.156051
#
#    customer_id                       ano_modelo                   modelo  \
# 0         7946  1994 Chevrolet 3500 Regular Cab  Dodge Caravan Passenger
#
#   fabricante ano_veiculo categoria                  dt_update
# 0        BMW        2001     Sedan 2024-08-18 13:36:53.174568
#
#    customer_id          ano_modelo        modelo fabricante ano_veiculo  \
# 0         4284  2008 Chevrolet HHR  MAZDA MAZDA5  Chevrolet        1995
#
#   categoria                  dt_update
# 0     Sedan 2024-08-18 13:36:53.192589
#
#    customer_id                ano_modelo            modelo fabricante  \
# 0         6948  1999 Ford F250 Super Cab  Cadillac Allante    Hyundai
#
#   ano_veiculo categoria                  dt_update
# 0        2019       SUV 2024-08-18 13:36:53.210612
#
#    customer_id                           ano_modelo        modelo fabricante  \
# 0          626  2016 Mercedes-Benz Mercedes-AMG CLA  Nissan Versa      Volvo
#
#   ano_veiculo categoria                  dt_update
# 0        2010    Pickup 2024-08-18 13:36:53.228619
#
#    customer_id          ano_modelo                            modelo  \
# 0         7235  2014 Hyundai Azera  Chevrolet Express 3500 Passenger
#
#   fabricante ano_veiculo           categoria                  dt_update
# 0     Nissan        2004  Coupe, Convertible 2024-08-18 13:36:53.246593
#
#    customer_id        ano_modelo       modelo fabricante ano_veiculo  \
# 0         9054  1996 Buick Regal  Kia Spectra     Toyota        1997
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:53.265108
#
#    customer_id                             ano_modelo  \
# 0         4566  2004 Chevrolet Express 2500 Passenger
#
#                            modelo fabricante ano_veiculo categoria  \
# 0  Mercedes-Benz Metris Passenger     Jaguar        2020     Sedan
#
#                    dt_update
# 0 2024-08-18 13:36:53.282619
#
#    customer_id     ano_modelo           modelo     fabricante ano_veiculo  \
# 0         1270  2001 Lexus IS  Hyundai Elantra  Mercedes-Benz        2017
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:53.300741
#
#    customer_id                  ano_modelo    modelo fabricante ano_veiculo  \
# 0         9654  2014 Cadillac Escalade ESV  Scion xA      Lexus        2014
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:53.318255
#
#    customer_id                  ano_modelo  \
# 0         3716  1998 GMC Savana 3500 Cargo
#
#                                modelo fabricante ano_veiculo  categoria  \
# 0  smart fortwo electric drive cabrio   Plymouth        2013  Hatchback
#
#                    dt_update
# 0 2024-08-18 13:36:53.336348
#
#    customer_id                ano_modelo            modelo fabricante  \
# 0         3815  2011 Rolls-Royce Phantom  MINI Convertible      Eagle
#
#   ano_veiculo categoria                  dt_update
# 0        2005     Sedan 2024-08-18 13:36:53.355368
#
#    customer_id           ano_modelo        modelo fabricante ano_veiculo  \
# 0         4917  1993 Suzuki Samurai  BMW 5 Series        BMW        2016
#
#                    categoria                  dt_update
# 0  Convertible, Coupe, Sedan 2024-08-18 13:36:53.373880
#
#    customer_id                    ano_modelo          modelo fabricante  \
# 0         1391  1994 Toyota T100 Regular Cab  Hyundai Tucson     Nissan
#
#   ano_veiculo    categoria                  dt_update
# 0        1994  Van/Minivan 2024-08-18 13:36:53.391886
#
#    customer_id             ano_modelo             modelo fabricante  \
# 0          650  1996 Ford Thunderbird  Mitsubishi 3000GT     Toyota
#
#   ano_veiculo categoria                  dt_update
# 0        2020       SUV 2024-08-18 13:36:53.410910
#
#    customer_id               ano_modelo                      modelo  \
# 0         9103  2013 Ford Expedition EL  Ford E250 Super Duty Cargo
#
#   fabricante ano_veiculo categoria                  dt_update
# 0    Hyundai        1994     Coupe 2024-08-18 13:36:53.427917
#
#    customer_id             ano_modelo         modelo fabricante ano_veiculo  \
# 0         3682  2006 Chevrolet Cobalt  Nissan Murano    Hyundai        2014
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:53.445938
#
#    customer_id       ano_modelo               modelo fabricante ano_veiculo  \
# 0         2461  2016 Scion FR-S  Toyota Land Cruiser     Nissan        2019
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:53.462945
#
#    customer_id                                     ano_modelo    modelo  \
# 0         2074  2001 Ford Econoline E350 Super Duty Passenger  Lexus RX
#
#   fabricante ano_veiculo categoria                  dt_update
# 0        Kia        2011     Sedan 2024-08-18 13:36:53.480965
#
#    customer_id     ano_modelo       modelo  fabricante ano_veiculo  \
# 0         9174  2013 Lexus ES  Ford Escort  Land Rover        2019
#
#      categoria                  dt_update
# 0  Convertible 2024-08-18 13:36:53.498477
#
#    customer_id     ano_modelo                        modelo fabricante  \
# 0         6566  2019 Lexus RX  GMC Sierra 2500 Extended Cab    Pontiac
#
#   ano_veiculo categoria                  dt_update
# 0        1993     Sedan 2024-08-18 13:36:53.516094
#
#    customer_id             ano_modelo                   modelo fabricante  \
# 0         2609  2007 Mercury Monterey  Chrysler Town & Country   Cadillac
#
#   ano_veiculo categoria                  dt_update
# 0        2009       SUV 2024-08-18 13:36:53.534121
#
#    customer_id       ano_modelo    modelo     fabricante ano_veiculo  \
# 0         9775  1998 Kia Sephia  Lexus GX  Mercedes-Benz        2017
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:53.551638
#
#    customer_id       ano_modelo            modelo    fabricante ano_veiculo  \
# 0         6476  2013 Suzuki SX4  Chrysler Sebring  Aston Martin        1994
#
#   categoria                  dt_update
# 0     Sedan 2024-08-18 13:36:53.570223
#
#    customer_id                                    ano_modelo  \
# 0         1784  2002 Chevrolet Silverado 2500 HD Regular Cab
#
#                                   modelo fabricante ano_veiculo    categoria  \
# 0  Chevrolet Silverado 3500 Extended Cab     Toyota        2014  Van/Minivan
#
#                    dt_update
# 0 2024-08-18 13:36:53.587686
#
#    customer_id           ano_modelo       modelo fabricante ano_veiculo  \
# 0         9969  2008 Land Rover LR3  Nissan GT-R    Lincoln        2004
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:53.605205
#
#    customer_id         ano_modelo    modelo fabricante ano_veiculo categoria  \
# 0         5002  2015 INFINITI Q70  Scion xB        Ram        2007    Pickup
#
#                    dt_update
# 0 2024-08-18 13:36:53.623156
#
#    customer_id                          ano_modelo  \
# 0         3970  2015 GMC Sierra 2500 HD Double Cab
#
#                           modelo fabricante ano_veiculo categoria  \
# 0  Dodge Sprinter 2500 Passenger      Dodge        2013       SUV
#
#                    dt_update
# 0 2024-08-18 13:36:53.640174
#
#    customer_id                    ano_modelo  modelo  fabricante ano_veiculo  \
# 0         1106  2008 GMC Canyon Extended Cab  BMW M5  Mitsubishi        2014
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:53.657691
#
#    customer_id                          ano_modelo  \
# 0         9926  2018 GMC Sierra 3500 HD Double Cab
#
#                            modelo     fabricante ano_veiculo categoria  \
# 0  Chevrolet 2500 HD Extended Cab  Mercedes-Benz        2009    Pickup
#
#                    dt_update
# 0 2024-08-18 13:36:53.676204
#
#    customer_id              ano_modelo        modelo fabricante ano_veiculo  \
# 0         8737  2019 Mercedes-Benz GLC  Cadillac CTS      Dodge        2013
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:53.695730
#
#    customer_id                  ano_modelo                 modelo  \
# 0         3247  2003 Chevrolet Monte Carlo  Ford F150 Regular Cab
#
#       fabricante ano_veiculo categoria                  dt_update
# 0  Mercedes-Benz        2004     Wagon 2024-08-18 13:36:53.714337
#
#    customer_id                      ano_modelo     modelo     fabricante  \
# 0         5352  1995 Ford Econoline E350 Cargo  Acura MDX  Mercedes-Benz
#
#   ano_veiculo categoria                  dt_update
# 0        2015    Pickup 2024-08-18 13:36:53.732853
#
#    customer_id   ano_modelo        modelo fabricante ano_veiculo    categoria  \
# 0         7090  2007 BMW Z4  Buick Encore        GMC        2016  Convertible
#
#                    dt_update
# 0 2024-08-18 13:36:53.750874
#
#    customer_id     ano_modelo    modelo fabricante ano_veiculo  \
# 0         9034  1999 Lexus GS  Acura TL  Chevrolet        2016
#
#             categoria                  dt_update
# 0  Coupe, Convertible 2024-08-18 13:36:53.769487
#
#    customer_id                  ano_modelo       modelo fabricante  \
# 0          112  2004 Mercedes-Benz M-Class  Nissan LEAF  Chevrolet
#
#   ano_veiculo  categoria                  dt_update
# 0        2016  Hatchback 2024-08-18 13:36:53.787498
#
#    customer_id          ano_modelo    modelo fabricante ano_veiculo  \
# 0         4980  2006 Subaru Legacy  Acura TL      MAZDA        2009
#
#       categoria                  dt_update
# 0  Sedan, Coupe 2024-08-18 13:36:53.806358
#
#    customer_id                ano_modelo   modelo fabricante ano_veiculo  \
# 0         2979  2020 Toyota Camry Hybrid  Audi S3   Chrysler        2004
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:53.824975
#
#    customer_id      ano_modelo                     modelo fabricante  \
# 0         2322  2019 Honda Fit  GMC Savana 2500 Passenger       FIAT
#
#   ano_veiculo    categoria                  dt_update
# 0        2013  Van/Minivan 2024-08-18 13:36:53.843008
#
#    customer_id              ano_modelo           modelo fabricante  \
# 0         3055  1993 Buick Park Avenue  Honda Ridgeline    Bentley
#
#   ano_veiculo  categoria                  dt_update
# 0        2010  Hatchback 2024-08-18 13:36:53.861530
#
#    customer_id    ano_modelo             modelo fabricante ano_veiculo  \
# 0          346  2020 Audi A7  Isuzu Regular Cab     Toyota        2009
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:53.880046
#
#    customer_id         ano_modelo     modelo fabricante ano_veiculo categoria  \
# 0         5134  2012 Nissan Versa  FIAT 500e       Ford        2005       SUV
#
#                    dt_update
# 0 2024-08-18 13:36:53.898058
#
#    customer_id                  ano_modelo              modelo fabricante  \
# 0         7580  2006 Mercedes-Benz E-Class  Nissan Rogue Sport      Dodge
#
#   ano_veiculo categoria                  dt_update
# 0        2014       SUV 2024-08-18 13:36:53.917200
#
#    customer_id                              ano_modelo  \
# 0         3315  2016 Mercedes-Benz Sprinter 2500 Cargo
#
#                         modelo fabricante ano_veiculo    categoria  \
# 0  Suzuki Equator Extended Cab       Audi        2004  Van/Minivan
#
#                    dt_update
# 0 2024-08-18 13:36:53.936231
#
#    customer_id      ano_modelo     modelo fabricante ano_veiculo categoria  \
# 0         7446  1994 Volvo 850  Jaguar XJ  Chevrolet        2017    Pickup
#
#                    dt_update
# 0 2024-08-18 13:36:53.954745
#
#    customer_id                    ano_modelo      modelo fabricante  \
# 0         5852  1997 Dodge Ram 2500 Club Cab  Kia Optima       Jeep
#
#   ano_veiculo categoria                  dt_update
# 0        2013     Sedan 2024-08-18 13:36:53.973261
#
#    customer_id           ano_modelo                   modelo    fabricante  \
# 0         1344  1993 Toyota 4Runner  Mercedes-Benz GLE Coupe  Freightliner
#
#   ano_veiculo categoria                  dt_update
# 0        1994       SUV 2024-08-18 13:36:53.991226
#
#    customer_id                  ano_modelo           modelo fabricante  \
# 0         7149  2006 Mercury Grand Marquis  Ford Expedition      MAZDA
#
#   ano_veiculo categoria                  dt_update
# 0        2011       SUV 2024-08-18 13:36:54.009267
#
#    customer_id     ano_modelo                  modelo fabricante ano_veiculo  \
# 0          803  1997 Saab 900  Mercedes-Benz SL-Class  Chevrolet        1995
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:54.027276
#
#    customer_id               ano_modelo     modelo fabricante ano_veiculo  \
# 0         7922  1997 Ford F250 Crew Cab  Saab 9-2X      MAZDA        2015
#
#   categoria                  dt_update
# 0     Wagon 2024-08-18 13:36:54.045315
#
#    customer_id          ano_modelo     modelo fabricante ano_veiculo  \
# 0         3463  2005 Toyota Sienna  Volvo S70   Cadillac        2000
#
#   categoria                  dt_update
# 0     Coupe 2024-08-18 13:36:54.065837
#
#    customer_id               ano_modelo   modelo fabricante ano_veiculo  \
# 0         7354  2008 Mitsubishi Eclipse  Audi TT      Acura        2020
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:54.085854
#
#    customer_id                ano_modelo                          modelo  \
# 0         7376  1995 Ford Crown Victoria  Ford F350 Super Duty Super Cab
#
# ...
# 0         2834  2012 Chevrolet Equinox  Volkswagen Golf  Chevrolet
#
#   ano_veiculo                  categoria                  dt_update
# 0        2018  Sedan, Convertible, Coupe 2024-08-18 13:36:55.159587
#
#    customer_id                         ano_modelo                   modelo  \
# 0         5292  2010 Land Rover Range Rover Sport  Ram ProMaster Cargo Van
#
#   fabricante ano_veiculo categoria                  dt_update
# 0      Dodge        2002    Pickup 2024-08-18 13:36:55.179107
#
#    customer_id          ano_modelo                 modelo fabricante  \
# 0         1533  2009 Toyota Sienna  Ford Ranger Super Cab   INFINITI
#
#   ano_veiculo    categoria                  dt_update
# 0        1992  Van/Minivan 2024-08-18 13:36:55.199141
#
#    customer_id        ano_modelo              modelo fabricante ano_veiculo  \
# 0         3064  2011 Honda Civic  Dodge Ram Van B350    Hyundai        2009
#
#   categoria                  dt_update
# 0     Coupe 2024-08-18 13:36:55.217878
#
#    customer_id            ano_modelo          modelo fabricante ano_veiculo  \
# 0         3989  1997 Ford Expedition  Hyundai Accent  Chevrolet        2006
#
#   categoria                  dt_update
# 0     Sedan 2024-08-18 13:36:55.238917
#
#    customer_id                                    ano_modelo          modelo  \
# 0         3975  2002 Chevrolet Silverado 2500 HD Regular Cab  Toyota Sequoia
#
#   fabricante ano_veiculo categoria                  dt_update
# 0   Chrysler        2005     Coupe 2024-08-18 13:36:55.262435
#
#    customer_id          ano_modelo       modelo fabricante ano_veiculo  \
# 0          261  2018 Honda Odyssey  Ford Escort   Cadillac        2008
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:55.286960
#
#    customer_id        ano_modelo      modelo fabricante ano_veiculo categoria  \
# 0         4888  2002 Isuzu Axiom  MAZDA MX-6   INFINITI        2005     Sedan
#
#                    dt_update
# 0 2024-08-18 13:36:55.310553
#
#    customer_id         ano_modelo      modelo fabricante ano_veiculo  \
# 0         3185  2003 Toyota Camry  Volvo XC70     Toyota        1995
#
#       categoria                  dt_update
# 0  Sedan, Wagon 2024-08-18 13:36:55.330656
#
#    customer_id      ano_modelo                                modelo  \
# 0         5281  2003 Volvo S80  Chevrolet Silverado 2500 HD Crew Cab
#
#   fabricante ano_veiculo                categoria                  dt_update
# 0      Buick        1997  Hatchback, Sedan, Wagon 2024-08-18 13:36:55.350690
#
#    customer_id                  ano_modelo     modelo fabricante ano_veiculo  \
# 0         3040  2013 Nissan Titan King Cab  Saab 9000        GMC        2019
#
#   categoria                  dt_update
# 0     Sedan 2024-08-18 13:36:55.370211
#
#    customer_id          ano_modelo                 modelo fabricante  \
# 0         6280  2003 Jaguar S-Type  Nissan Titan Crew Cab     Toyota
#
#   ano_veiculo categoria                  dt_update
# 0        1992       SUV 2024-08-18 13:36:55.390229
#
#    customer_id                          ano_modelo      modelo fabricante  \
# 0         7887  2008 Dodge Grand Caravan Passenger  Subaru BRZ     Subaru
#
#   ano_veiculo           categoria                  dt_update
# 0        2018  Sedan, Convertible 2024-08-18 13:36:55.409173
#
#    customer_id       ano_modelo         modelo fabricante ano_veiculo  \
# 0         6240  2007 Kia Optima  Honda Prelude       Saab        2001
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:55.427683
#
#    customer_id     ano_modelo   modelo fabricante ano_veiculo    categoria  \
# 0         5569  2019 FIAT 500  Audi S3    Hyundai        2011  Van/Minivan
#
#                    dt_update
# 0 2024-08-18 13:36:55.446380
#
#    customer_id              ano_modelo  modelo  fabricante ano_veiculo  \
# 0         5630  2007 Hyundai Entourage  BMW X3  Oldsmobile        1994
#
#       categoria                  dt_update
# 0  Sedan, Coupe 2024-08-18 13:36:55.464990
#
#    customer_id               ano_modelo       modelo fabricante ano_veiculo  \
# 0         1121  2009 Bentley Brooklands  Ford Taurus      Honda        2015
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:55.483466
#
#    customer_id         ano_modelo        modelo fabricante ano_veiculo  \
# 0         8104  2006 Cadillac CTS  Nissan Versa       Audi        2019
#
#   categoria                  dt_update
# 0     Sedan 2024-08-18 13:36:55.501986
#
#    customer_id                            ano_modelo      modelo fabricante  \
# 0         9476  1993 Mitsubishi Mighty Max Macro Cab  Dodge Neon    Hyundai
#
#   ano_veiculo categoria                  dt_update
# 0        2018    Pickup 2024-08-18 13:36:55.521612
#
#    customer_id    ano_modelo    modelo  fabricante ano_veiculo categoria  \
# 0         6798  2004 Audi A4  Lexus ES  Mitsubishi        2007     Sedan
#
#                    dt_update
# 0 2024-08-18 13:36:55.540767
#
#    customer_id      ano_modelo                          modelo fabricante  \
# 0         3249  2002 Acura MDX  Ford F250 Super Duty Super Cab     Toyota
#
#   ano_veiculo    categoria                  dt_update
# 0        2012  Van/Minivan 2024-08-18 13:36:55.560283
#
#    customer_id              ano_modelo                         modelo  \
# 0         2492  2000 Volkswagen Cabrio  Ford F350 Super Duty Crew Cab
#
#   fabricante ano_veiculo categoria                  dt_update
# 0       Ford        2008       SUV 2024-08-18 13:36:55.579822
#
#    customer_id                ano_modelo                         modelo  \
# 0         4432  2006 Kia Optima (2006.5)  Hyundai Sonata Plug-in Hybrid
#
#   fabricante ano_veiculo categoria                  dt_update
# 0        GMC        2001     Sedan 2024-08-18 13:36:55.600033
#
#    customer_id                  ano_modelo            modelo fabricante  \
# 0         7084  1992 Chevrolet Astro Cargo  Cadillac DeVille      Volvo
#
#   ano_veiculo categoria                  dt_update
# 0        2015     Sedan 2024-08-18 13:36:55.620555
#
#    customer_id            ano_modelo        modelo     fabricante ano_veiculo  \
# 0         6451  2001 Cadillac Catera  Kia Sportage  Mercedes-Benz        2017
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:55.640291
#
#    customer_id                ano_modelo     modelo fabricante ano_veiculo  \
# 0         4177  2015 Subaru XV Crosstrek  Honda Fit       Jeep        2000
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:55.661812
#
#    customer_id          ano_modelo        modelo fabricante ano_veiculo  \
# 0         9930  2007 Hyundai Azera  BMW 6 Series   INFINITI        2000
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:55.681327
#
#    customer_id          ano_modelo                             modelo  \
# 0         5915  2011 MAZDA Tribute  Chevrolet Silverado 1500 Crew Cab
#
#   fabricante ano_veiculo                  categoria                  dt_update
# 0  Chevrolet        2008  Wagon, Convertible, Sedan 2024-08-18 13:36:55.700294
#
#    customer_id                      ano_modelo                        modelo  \
# 0         5380  1996 GMC Savana 3500 Passenger  Land Rover Range Rover Sport
#
#   fabricante ano_veiculo categoria                  dt_update
# 0      Dodge        2004       SUV 2024-08-18 13:36:55.720229
#
#    customer_id             ano_modelo           modelo fabricante ano_veiculo  \
# 0         3206  2019 MAZDA MX-5 Miata  Chevrolet Sonic       Audi        2019
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:55.739131
#
#    customer_id             ano_modelo              modelo fabricante  \
# 0         9950  2018 Rolls-Royce Dawn  Chevrolet Corvette     Suzuki
#
#   ano_veiculo     categoria                  dt_update
# 0        2005  Sedan, Wagon 2024-08-18 13:36:55.758648
#
#    customer_id                   ano_modelo                 modelo fabricante  \
# 0         1257  1992 Dodge D250 Regular Cab  Ford F250 Regular Cab      Acura
#
#   ano_veiculo                categoria                  dt_update
# 0        2001  Coupe, Hatchback, Sedan 2024-08-18 13:36:55.777444
#
#    customer_id               ano_modelo            modelo fabricante  \
# 0         2720  2002 Chevrolet Cavalier  Pontiac Firebird       Ford
#
#   ano_veiculo categoria                  dt_update
# 0        2015       SUV 2024-08-18 13:36:55.797142
#
#    customer_id        ano_modelo                   modelo fabricante  \
# 0         8368  2010 Honda Civic  GMC Sonoma Extended Cab  Chevrolet
#
#   ano_veiculo categoria                  dt_update
# 0        1993    Pickup 2024-08-18 13:36:55.815412
#
#    customer_id                              ano_modelo           modelo  \
# 0         8724  2004 Chevrolet Silverado 1500 Crew Cab  FIAT 124 Spider
#
#   fabricante ano_veiculo               categoria                  dt_update
# 0      Acura        2011  Hatchback, Convertible 2024-08-18 13:36:55.833433
#
#    customer_id              ano_modelo                 modelo fabricante  \
# 0         8501  1993 Chrysler Imperial  Toyota Tacoma Xtracab    Porsche
#
#   ano_veiculo           categoria                  dt_update
# 0        1996  Coupe, Convertible 2024-08-18 13:36:55.853011
#
#    customer_id                 ano_modelo                      modelo  \
# 0         3645  2000 Dodge Ram Wagon 2500  Chevrolet 3500 Regular Cab
#
#   fabricante ano_veiculo categoria                  dt_update
# 0      Lexus        2014    Pickup 2024-08-18 13:36:55.873169
#
#    customer_id                  ano_modelo         modelo fabricante  \
# 0         5096  2014 Mercedes-Benz E-Class  INFINITI QX80      Dodge
#
#   ano_veiculo categoria                  dt_update
# 0        2013       SUV 2024-08-18 13:36:55.892209
#
#    customer_id                     ano_modelo      modelo   fabricante  \
# 0         4836  1995 Oldsmobile Cutlass Ciera  Honda CR-V  Rolls-Royce
#
#   ano_veiculo categoria                  dt_update
# 0        1995       SUV 2024-08-18 13:36:55.911089
#
#    customer_id         ano_modelo          modelo fabricante ano_veiculo  \
# 0         6528  2014 MAZDA MAZDA2  Cadillac ATS-V       Audi        2019
#
#    categoria                  dt_update
# 0  Hatchback 2024-08-18 13:36:55.928915
#
#    customer_id          ano_modelo              modelo fabricante ano_veiculo  \
# 0         5967  2011 Honda Insight  Chevrolet Traverse     Subaru        1999
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:55.946600
#
#    customer_id              ano_modelo       modelo fabricante ano_veiculo  \
# 0         5159  2019 Volkswagen Beetle  Lincoln MKT       Ford        2000
#
#   categoria                  dt_update
# 0    Pickup 2024-08-18 13:36:55.963763
#
#    customer_id               ano_modelo       modelo fabricante ano_veiculo  \
# 0          478  2016 Ram ProMaster City  Ford Escape  Chevrolet        2015
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:55.982070
#
#    customer_id                     ano_modelo            modelo fabricante  \
# 0         9627  2009 Nissan Frontier King Cab  Dodge Challenger      Dodge
#
#   ano_veiculo           categoria                  dt_update
# 0        2000  Coupe, Convertible 2024-08-18 13:36:56.000831
#
#    customer_id               ano_modelo   modelo fabricante ano_veiculo  \
# 0         1951  1995 Chevrolet Cavalier  Audi S8       Ford        2017
#
#   categoria                  dt_update
# 0     Sedan 2024-08-18 13:36:56.020158
#
#    customer_id           ano_modelo                    modelo fabricante  \
# 0         7031  2016 Subaru Outback  Nissan Frontier Crew Cab      MAZDA
#
#   ano_veiculo categoria                  dt_update
# 0        2004     Sedan 2024-08-18 13:36:56.038511
#
#    customer_id                    ano_modelo       modelo fabricante  \
# 0         4533  1997 Chevrolet 3500 Crew Cab  Nissan 370Z      Honda
#
#   ano_veiculo     categoria                  dt_update
# 0        2006  Sedan, Wagon 2024-08-18 13:36:56.057861
#
#    customer_id                    ano_modelo              modelo fabricante  \
# 0         1866  1995 Ford Ranger Regular Cab  Chevrolet Cavalier      Isuzu
#
#   ano_veiculo categoria                  dt_update
# 0        2005     Sedan 2024-08-18 13:36:56.077173
#
#    customer_id                             ano_modelo               modelo  \
# 0         4573  2016 Mercedes-Benz Sprinter 2500 Crew  Volkswagen Golf GTI
#
#   fabricante ano_veiculo categoria                  dt_update
# 0        GMC        2000    Pickup 2024-08-18 13:36:56.096036
#
#    customer_id                  ano_modelo               modelo fabricante  \
# 0         7380  2006 GMC Savana 2500 Cargo  Lincoln Navigator L        BMW
#
#   ano_veiculo categoria                  dt_update
# 0        1996     Sedan 2024-08-18 13:36:56.114460
#
#    customer_id         ano_modelo                                    modelo  \
# 0         1110  2017 BMW 7 Series  Chevrolet Silverado 2500 HD Extended Cab
#
#   fabricante ano_veiculo categoria                  dt_update
# 0   INFINITI        2009    Pickup 2024-08-18 13:36:56.133609
#
#    customer_id           ano_modelo                 modelo fabricante  \
# 0         2038  2000 Honda Passport  Land Rover Freelander        GMC
#
#   ano_veiculo                  categoria                  dt_update
# 0        2019  Convertible, Sedan, Coupe 2024-08-18 13:36:56.152324
#
#    customer_id      ano_modelo        modelo fabricante ano_veiculo categoria  \
# 0         4849  2008 Volvo S40  Toyota Venza    Porsche        1995    Pickup
#
#                    dt_update
# 0 2024-08-18 13:36:56.171848
#
#    customer_id       ano_modelo       modelo fabricante ano_veiculo  \
# 0         5697  2008 MAZDA CX-9  Buick Regal  Chevrolet        2008
#
#      categoria                  dt_update
# 0  Van/Minivan 2024-08-18 13:36:56.189983
#
#    customer_id                            ano_modelo    modelo fabricante  \
# 0         7007  2003 GMC Sierra 2500 HD Extended Cab  BMW X5 M  Chevrolet
#
#   ano_veiculo categoria                  dt_update
# 0        2009       SUV 2024-08-18 13:36:56.208314
#
#    customer_id     ano_modelo            modelo fabricante ano_veiculo  \
# 0         4314  2001 Acura RL  MAZDA MX-5 Miata        GMC        2020
#
#   categoria                  dt_update
# 0       SUV 2024-08-18 13:36:56.227320
#
#    customer_id           ano_modelo      modelo fabricante ano_veiculo  \
# 0         4332  2014 Chevrolet Volt  Pontiac G5      Honda        2001
#
#       categoria                  dt_update
# 0  Sedan, Coupe 2024-08-18 13:36:56.246342
#
#    customer_id                    ano_modelo                      modelo  \
# 0         7585  2014 Mercedes-Benz CLA-Class  Chevrolet 2500 Regular Cab
#
#   fabricante ano_veiculo    categoria                  dt_update
# 0      Dodge        1998  Convertible 2024-08-18 13:36:56.266177
#
#    customer_id              ano_modelo                     modelo fabricante  \
# 0         8337  2019 Mercedes-Benz GLS  Toyota Tacoma Regular Cab       Audi
#
#   ano_veiculo categoria                  dt_update
# 0        2007       SUV 2024-08-18 13:36:56.284691
#
#    customer_id                ano_modelo           modelo fabricante  \
# 0         6806  2001 Ford Windstar Cargo  MINI Countryman      Honda
#
#   ano_veiculo categoria                  dt_update
# 0        1999       SUV 2024-08-18 13:36:56.303353
#
#    customer_id    ano_modelo        modelo fabricante ano_veiculo  \
# 0         3353  2010 Audi Q5  BMW 5 Series  Chevrolet        1996
#
#             categoria                  dt_update
# 0  Convertible, Coupe 2024-08-18 13:36:56.321187
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 58
#      55 if not args.silent:
#      56     print(df, end="\n\n")
# ---> 58 time.sleep(args.interval)
#
# KeyboardInterrupt:
