# %%
import os
import time
import argparse
import pandas as pd
import numpy as np
from faker import Faker
from sqlalchemy import create_engine
from datetime import datetime
from dotenv import load_dotenv
from faker_airtravel import AirTravelProvider

load_dotenv()
# Out:
# True

# %%
username = os.environ.get("POSTGRES_DATABASE_USER")
password = os.environ.get("POSTGRES_PASSWORD")
host = os.environ.get("POSTGRES_HOST")
port = os.environ.get("POSTGRES_PORT")
database = os.environ.get("POSTGRES_DATABASE")
table = os.environ.get("POSTGRES_TABLE")

# %%
# função para parsear a saída do parâmetro SILENT
def str2bool(v):
    if isinstance(v, bool):
       return v
    if v.lower() in ('yes', 'true', 't', 'y', '1'):
        return True
    elif v.lower() in ('no', 'false', 'f', 'n', '0'):
        return False
    else:
        raise argparse.ArgumentTypeError('Boolean value expected.')

# %%
# Instancia a classe Faker
faker = Faker()
faker.add_provider(AirTravelProvider)

if __name__ == "__main__":

    parser = argparse.ArgumentParser(description='Generate fake data...')

    parser.add_argument('--interval', type=int, default=1,
                        help='interval of generating fake data in seconds')
    parser.add_argument('-n', type=int, default=1,
                        help='sample size')
    parser.add_argument('--connection-string', '-cs', dest="connection_string", 
                        type=str, default=f'postgresql://{username}:{password}@{host}:{port}/{database}',
                        help='Connection string to the database')
    parser.add_argument('--silent', type=str2bool, nargs='?',
                        const=True, default=False,
                        help="print fake data")

    args, unknown = parser.parse_known_args()

    print(f"Args parsed:")
    print(f"Interval: {args.interval}")
    print(f"Sample size; {args.n}")
    print(f"Connection string: {args.connection_string}", end='\n\n')

    #-----------------------------------------------------------------

    engine = create_engine(args.connection_string)

    print("Iniciando a simulacao...", end="\n\n")

    # Gera dados fake a faz ingestão
    while True:
        customer_id   = [faker.random_int() for i in range(args.n)]
        aeroporto    = [faker.airport_name() for i in range(args.n)]
        linha_aerea    = [faker.airline() for i in range(args.n)]
        cod_iata   = [faker.airport_iata() for i in range(args.n)]
        dt_update  = [datetime.now() for i in range(args.n)]

        df = pd.DataFrame({
            "customer_id":customer_id,
            "aeroporto": aeroporto,
            "linha_aerea": linha_aerea,
            "cod_iata": cod_iata,
            "dt_update": dt_update
        })

        df.to_sql("flight", con=engine, if_exists="append", index=False)

        if not args.silent:
            print(df, end="\n\n")

        time.sleep(args.interval)
# Out:
# Args parsed:
# Interval: 0.005
# Sample size; 1
# Connection string: postgresql://postgres:mantis0090a@localhost:5432/postgres
#
# Iniciando a simulacao...
#
#    customer_id                 aeroporto linha_aerea cod_iata  \
# 0         7670  Jorge Wilsterman airport  Air Canada      BNA
#
#                    dt_update
# 0 2024-08-18 13:35:01.261682
#
#    customer_id       aeroporto linha_aerea cod_iata                  dt_update
# 0         2717  Juanda airport    Cape Air      WUX 2024-08-18 13:35:01.327189
#
#    customer_id                aeroporto               linha_aerea cod_iata  \
# 0         3708  Cariri Regional airport  Beijing Capital Airlines      PEI
#
#                    dt_update
# 0 2024-08-18 13:35:01.347203
#
#    customer_id             aeroporto      linha_aerea cod_iata  \
# 0         8034  Rafael Nunez airport  Delta Air Lines      SVG
#
#                    dt_update
# 0 2024-08-18 13:35:01.366715
#
#    customer_id                aeroporto linha_aerea cod_iata  \
# 0         8668  Bergen Flesland airport    Oman Air      CGR
#
#                    dt_update
# 0 2024-08-18 13:35:01.385232
#
#    customer_id                                         aeroporto linha_aerea  \
# 0         1864  Governador Andre Franco Montoro International Ai       GoAir
#
#   cod_iata                  dt_update
# 0      BGY 2024-08-18 13:35:01.404030
#
#    customer_id aeroporto        linha_aerea cod_iata  \
# 0         1047    Belize  Frontier Airlines      CHS
#
#                    dt_update
# 0 2024-08-18 13:35:01.422684
#
#    customer_id                                    aeroporto  \
# 0         7222  Arturo Merino Benitez International airport
#
#                 linha_aerea cod_iata                  dt_update
# 0  Southern Airways Express      CEB 2024-08-18 13:35:01.440690
#
#    customer_id                aeroporto linha_aerea cod_iata  \
# 0         5143  Beijing Capital airport  Air Canada      IQT
#
#                    dt_update
# 0 2024-08-18 13:35:01.459206
#
#    customer_id      aeroporto      linha_aerea cod_iata  \
# 0         3994  Kirbi airport  Maya Island Air      SLA
#
#                    dt_update
# 0 2024-08-18 13:35:01.477075
#
#    customer_id                     aeroporto      linha_aerea cod_iata  \
# 0         4610  Catania Fontanarossa airport  Maya Island Air      GMP
#
#                    dt_update
# 0 2024-08-18 13:35:01.495593
#
#    customer_id                   aeroporto              linha_aerea cod_iata  \
# 0         9566  Bali International airport  China Southern Airlines      HRB
#
#                    dt_update
# 0 2024-08-18 13:35:01.512951
#
#    customer_id        aeroporto       linha_aerea cod_iata  \
# 0         3960  Blagnac airport  Tianjin Airlines      PUS
#
#                    dt_update
# 0 2024-08-18 13:35:01.530973
#
#    customer_id               aeroporto     linha_aerea cod_iata  \
# 0         2496  Zhangguizhuang airport  LATAM Airlines      SJC
#
#                    dt_update
# 0 2024-08-18 13:35:01.548098
#
#    customer_id                          aeroporto      linha_aerea cod_iata  \
# 0         7317  Kailua-Kona International airport  Air New Zealand      AMD
#
#                    dt_update
# 0 2024-08-18 13:35:01.565104
#
#    customer_id                                  aeroporto       linha_aerea  \
# 0         8636  Detroit Metropolitan Wayne County airport  Turkish Airlines
#
#   cod_iata                  dt_update
# 0      VLC 2024-08-18 13:35:01.582123
#
#    customer_id        aeroporto    linha_aerea cod_iata  \
# 0         1203  Hamburg airport  Sriwijaya Air      TFS
#
#                    dt_update
# 0 2024-08-18 13:35:01.598637
#
#    customer_id     aeroporto linha_aerea cod_iata                  dt_update
# 0         2208  Riga airport     Nam Air      CNX 2024-08-18 13:35:01.615464
#
#    customer_id                        aeroporto    linha_aerea cod_iata  \
# 0         4000  Capitan Oriel Lea Plaza airport  Qatar Airways      NQN
#
#                    dt_update
# 0 2024-08-18 13:35:01.633488
#
#    customer_id           aeroporto         linha_aerea cod_iata  \
# 0         1497  Boise Air Terminal  Southwest Airlines      HAK
#
#                    dt_update
# 0 2024-08-18 13:35:01.650494
#
#    customer_id                            aeroporto      linha_aerea cod_iata  \
# 0         2345  HAL Bangalore International airport  British Airways      CKG
#
#                    dt_update
# 0 2024-08-18 13:35:01.667516
#
#    customer_id           aeroporto      linha_aerea cod_iata  \
# 0         7798  Gothenburg airport  Air New Zealand      BCN
#
#                    dt_update
# 0 2024-08-18 13:35:01.684526
#
#    customer_id         aeroporto      linha_aerea cod_iata  \
# 0           92  Dangriga airport  Air New Zealand      CGN
#
#                    dt_update
# 0 2024-08-18 13:35:01.702041
#
#    customer_id                              aeroporto      linha_aerea  \
# 0         8233  Gilberto Freyre International airport  Royal Air Maroc
#
#   cod_iata                  dt_update
# 0      DUS 2024-08-18 13:35:01.719075
#
#    customer_id                 aeroporto      linha_aerea cod_iata  \
# 0         5164  Sesquicentenario airport  Maya Island Air      FUE
#
#                    dt_update
# 0 2024-08-18 13:35:01.737588
#
#    customer_id         aeroporto       linha_aerea cod_iata  \
# 0         3925  Iraklion airport  Chengdu Airlines      PTY
#
#                    dt_update
# 0 2024-08-18 13:35:01.754941
#
#    customer_id            aeroporto linha_aerea cod_iata  \
# 0         7888  Dafang Shen airport     AirAsia      XNN
#
#                    dt_update
# 0 2024-08-18 13:35:01.772964
#
#    customer_id         aeroporto              linha_aerea cod_iata  \
# 0         9478  Gustavia airport  China Southern Airlines      KUF
#
#                    dt_update
# 0 2024-08-18 13:35:01.791996
#
#    customer_id                    aeroporto    linha_aerea cod_iata  \
# 0         2852  Osaka International airport  Qatar Airways      RSW
#
#                    dt_update
# 0 2024-08-18 13:35:01.810581
#
#    customer_id              aeroporto linha_aerea cod_iata  \
# 0         5888  Prague Ruzyne airport    Cape Air      MAA
#
#                    dt_update
# 0 2024-08-18 13:35:01.830102
#
#    customer_id                             aeroporto      linha_aerea  \
# 0         3314  Mariscal Sucre International airport  Air New Zealand
#
#   cod_iata                  dt_update
# 0      SHE 2024-08-18 13:35:01.848626
#
#    customer_id                                aeroporto      linha_aerea  \
# 0         4414  Coronel Aviador Cesar Bombonato airport  Alaska Airlines
#
#   cod_iata                  dt_update
# 0      PVG 2024-08-18 13:35:01.866075
#
#    customer_id                                aeroporto    linha_aerea  \
# 0         7330  Southwest Florida International airport  Qatar Airways
#
#   cod_iata                  dt_update
# 0      PNZ 2024-08-18 13:35:01.884097
#
#    customer_id                             aeroporto  linha_aerea cod_iata  \
# 0          184  Chicago O'Hare International airport  S7 Airlines      FTE
#
#                    dt_update
# 0 2024-08-18 13:35:01.901955
#
#    customer_id                      aeroporto          linha_aerea cod_iata  \
# 0          386  El Alto International airport  Philippine Airlines      MSQ
#
#                    dt_update
# 0 2024-08-18 13:35:01.919977
#
#    customer_id           aeroporto      linha_aerea cod_iata  \
# 0         2408  Tolmachevo airport  Air New Zealand      SHE
#
#                    dt_update
# 0 2024-08-18 13:35:01.938987
#
#    customer_id           aeroporto            linha_aerea cod_iata  \
# 0         9417  Mingaladon airport  LOT - Polish Airlines      MAO
#
#                    dt_update
# 0 2024-08-18 13:35:01.959174
#
#    customer_id                 aeroporto         linha_aerea cod_iata  \
# 0          999  Singapore Changi airport  Southwest Airlines      HNL
#
#                    dt_update
# 0 2024-08-18 13:35:01.977685
#
#    customer_id                          aeroporto linha_aerea cod_iata  \
# 0         7284  San Antonio International airport   Air India      DCA
#
#                    dt_update
# 0 2024-08-18 13:35:01.994697
#
#    customer_id        aeroporto      linha_aerea cod_iata  \
# 0         6848  Ynukovo airport  JetBlue Airways      FOR
#
#                    dt_update
# 0 2024-08-18 13:35:02.011716
#
#    customer_id                aeroporto linha_aerea cod_iata  \
# 0         3679  Bergen Flesland airport    Cape Air      CUN
#
#                    dt_update
# 0 2024-08-18 13:35:02.028724
#
#    customer_id                          aeroporto linha_aerea cod_iata  \
# 0         3874  Val de Caes International airport   Batik Air      ZCO
#
#                    dt_update
# 0 2024-08-18 13:35:02.045878
#
#    customer_id     aeroporto       linha_aerea cod_iata  \
# 0         3166  Faro airport  Sichuan Airlines      CRD
#
#                    dt_update
# 0 2024-08-18 13:35:02.063900
#
#    customer_id                        aeroporto             linha_aerea  \
# 0         1939  Los Cabos International airport  China Eastern Airlines
#
#   cod_iata                  dt_update
# 0      FLL 2024-08-18 13:35:02.080416
#
#    customer_id                     aeroporto       linha_aerea cod_iata  \
# 0         6349  Kansai International airport  Turkish Airlines      JFK
#
#                    dt_update
# 0 2024-08-18 13:35:02.097934
#
#    customer_id         aeroporto      linha_aerea cod_iata  \
# 0         5823  Alicante airport  JetBlue Airways      ANC
#
#                    dt_update
# 0 2024-08-18 13:35:02.114941
#
#    customer_id                      aeroporto       linha_aerea cod_iata  \
# 0         8212  Spokane International airport  Cebu Pacific Air      BOM
#
#                    dt_update
# 0 2024-08-18 13:35:02.132456
#
#    customer_id                                aeroporto linha_aerea cod_iata  \
# 0         9530  Coronel Aviador Cesar Bombonato airport  Air Canada      ZCO
#
#                    dt_update
# 0 2024-08-18 13:35:02.149972
#
#    customer_id                           aeroporto linha_aerea cod_iata  \
# 0         7965  Indianapolis International airport    Oman Air      ATH
#
#                    dt_update
# 0 2024-08-18 13:35:02.167623
#
#    customer_id                               aeroporto linha_aerea cod_iata  \
# 0          509  Bahia Blanca Cte Espora Naval Air Base     Nam Air      PUS
#
#                    dt_update
# 0 2024-08-18 13:35:02.186613
#
#    customer_id        aeroporto       linha_aerea cod_iata  \
# 0         9733  Palermo airport  Sichuan Airlines      YHZ
#
#                    dt_update
# 0 2024-08-18 13:35:02.205101
#
#    customer_id                  aeroporto       linha_aerea cod_iata  \
# 0         5846  Palma de Mallorca airport  Sichuan Airlines      ORD
#
#                    dt_update
# 0 2024-08-18 13:35:02.224134
#
#    customer_id                              aeroporto        linha_aerea  \
# 0         2029  King Abdul Aziz International airport  Shenzhen Airlines
#
#   cod_iata                  dt_update
# 0      TIA 2024-08-18 13:35:02.241874
#
#    customer_id           aeroporto      linha_aerea cod_iata  \
# 0         3943  Paris Orly airport  Hainan Airlines      MGF
#
#                    dt_update
# 0 2024-08-18 13:35:02.260894
#
#    customer_id       aeroporto      linha_aerea cod_iata  \
# 0         5767  Cancun airport  JetBlue Airways      RAO
#
#                    dt_update
# 0 2024-08-18 13:35:02.279904
#
#    customer_id      aeroporto            linha_aerea cod_iata  \
# 0         8531  Kirbi airport  LOT - Polish Airlines      AER
#
#                    dt_update
# 0 2024-08-18 13:35:02.297926
#
#    customer_id        aeroporto       linha_aerea cod_iata  \
# 0         8042  Liuting airport  Juneyao Airlines      MCM
#
#                    dt_update
# 0 2024-08-18 13:35:02.315933
#
#    customer_id            aeroporto        linha_aerea cod_iata  \
# 0          774  New Chitose airport  Shenzhen Airlines      LUX
#
#                    dt_update
# 0 2024-08-18 13:35:02.333952
#
#    customer_id       aeroporto linha_aerea cod_iata                  dt_update
# 0         5301  Dongta airport   Lucky Air      CGN 2024-08-18 13:35:02.351959
#
#    customer_id                           aeroporto linha_aerea cod_iata  \
# 0         6722  Berlin-Tegel International airport    Oman Air      DME
#
#                    dt_update
# 0 2024-08-18 13:35:02.370166
#
#    customer_id                    aeroporto      linha_aerea cod_iata  \
# 0         7924  Dubai International airport  Xiamen Airlines      SKG
#
#                    dt_update
# 0 2024-08-18 13:35:02.387447
#
#    customer_id                       aeroporto             linha_aerea  \
# 0         4992  Mehrabad International airport  China Eastern Airlines
#
#   cod_iata                  dt_update
# 0      DEL 2024-08-18 13:35:02.404965
#
#    customer_id                     aeroporto            linha_aerea cod_iata  \
# 0         7848  Cataratas del Iguazu airport  China United Airlines      VCE
#
#                    dt_update
# 0 2024-08-18 13:35:02.421994
#
#    customer_id                      aeroporto       linha_aerea cod_iata  \
# 0         2770  Calgary International airport  Vietnam Airlines      MDW
#
#                    dt_update
# 0 2024-08-18 13:35:02.440003
#
#    customer_id                                        aeroporto  \
# 0         4281  Fort Lauderdale Hollywood International airport
#
#        linha_aerea cod_iata                  dt_update
# 0  Spring Airlines      SPR 2024-08-18 13:35:02.457521
#
#    customer_id                  aeroporto      linha_aerea cod_iata  \
# 0         1191  Chengdushuang Liu airport  Delta Air Lines      WUX
#
#                    dt_update
# 0 2024-08-18 13:35:02.475039
#
#    customer_id                             aeroporto      linha_aerea  \
# 0         1183  Gerald R. Ford International airport  Spring Airlines
#
#   cod_iata                  dt_update
# 0      KGD 2024-08-18 13:35:02.492557
#
#    customer_id                          aeroporto        linha_aerea cod_iata  \
# 0         9206  Cap J A Quinones Gonzales airport  Shenzhen Airlines      UDI
#
#                    dt_update
# 0 2024-08-18 13:35:02.509076
#
#    customer_id             aeroporto        linha_aerea cod_iata  \
# 0         2953  Monte Carlo Heliport  Frontier Airlines      ORF
#
#                    dt_update
# 0 2024-08-18 13:35:02.525101
#
#    customer_id                                       aeroporto  \
# 0          850  Norman Y Mineta San Jose International airport
#
#         linha_aerea cod_iata                  dt_update
# 0  Chengdu Airlines      DTW 2024-08-18 13:35:02.542621
#
#    customer_id                        aeroporto linha_aerea cod_iata  \
# 0         5672  Los Cabos International airport   Batik Air      VKO
#
#                    dt_update
# 0 2024-08-18 13:35:02.559262
#
#    customer_id              aeroporto             linha_aerea cod_iata  \
# 0         5139  Mar del Plata airport  China Eastern Airlines      ANF
#
#                    dt_update
# 0 2024-08-18 13:35:02.576780
#
#    customer_id         aeroporto linha_aerea cod_iata  \
# 0         5989  Alicante airport    Lion Air      HET
#
#                    dt_update
# 0 2024-08-18 13:35:02.593806
#
#    customer_id                         aeroporto     linha_aerea cod_iata  \
# 0          282  Pittsburgh International airport  LATAM Airlines      CJC
#
#                    dt_update
# 0 2024-08-18 13:35:02.611321
#
#    customer_id          aeroporto      linha_aerea cod_iata  \
# 0         7579  Wuchia Pa airport  Spring Airlines      SLC
#
#                    dt_update
# 0 2024-08-18 13:35:02.628328
#
#    customer_id       aeroporto        linha_aerea cod_iata  \
# 0         1705  Cancun airport  Shandong Airlines      XNN
#
#                    dt_update
# 0 2024-08-18 13:35:02.644542
#
#    customer_id         aeroporto linha_aerea cod_iata  \
# 0           58  Alicante airport    Lion Air      HET
#
#                    dt_update
# 0 2024-08-18 13:35:02.661057
#
#    customer_id                    aeroporto  linha_aerea cod_iata  \
# 0         6469  Ataturk Hava Limani airport  VietJet Air      HNL
#
#                    dt_update
# 0 2024-08-18 13:35:02.678572
#
#    customer_id               aeroporto         linha_aerea cod_iata  \
# 0         4634  Tromso Langnes airport  Southwest Airlines      KHN
#
#                    dt_update
# 0 2024-08-18 13:35:02.696085
#
#    customer_id                    aeroporto       linha_aerea cod_iata  \
# 0         6027  Gimpo International airport  Turkish Airlines      USH
#
#                    dt_update
# 0 2024-08-18 13:35:02.713833
#
#    customer_id                            aeroporto       linha_aerea  \
# 0         3710  Simon Bolivar International airport  Tianjin Airlines
#
#   cod_iata                  dt_update
# 0      CUC 2024-08-18 13:35:02.782180
#
#    customer_id                              aeroporto linha_aerea cod_iata  \
# 0         4970  Prinses Juliana International airport     Nok Air      NQN
#
#                    dt_update
# 0 2024-08-18 13:35:02.800188
#
#    customer_id       aeroporto       linha_aerea cod_iata  \
# 0          752  Piarco airport  Turkish Airlines      DXB
#
#                    dt_update
# 0 2024-08-18 13:35:02.817705
#
#    customer_id                    aeroporto  linha_aerea cod_iata  \
# 0         5102  Tokyo International airport  S7 Airlines      BUD
#
#                    dt_update
# 0 2024-08-18 13:35:02.835731
#
#    customer_id         aeroporto       linha_aerea cod_iata  \
# 0         7570  Shenzhen airport  Chengdu Airlines      JDO
#
#                    dt_update
# 0 2024-08-18 13:35:02.853740
#
#    customer_id          aeroporto      linha_aerea cod_iata  \
# 0         4655  Stuttgart airport  Hainan Airlines      SSA
#
#                    dt_update
# 0 2024-08-18 13:35:02.871259
#
#    customer_id      aeroporto linha_aerea cod_iata                  dt_update
# 0         1482  Salta airport    Jeju Air      ANC 2024-08-18 13:35:02.890285
#
#    customer_id aeroporto linha_aerea cod_iata                  dt_update
# 0         3206      Wuxi   Air India      NRT 2024-08-18 13:35:02.907801
#
#    customer_id         aeroporto            linha_aerea cod_iata  \
# 0         4565  Schiphol airport  China United Airlines      ROV
#
#                    dt_update
# 0 2024-08-18 13:35:02.926320
#
#    customer_id                      aeroporto      linha_aerea cod_iata  \
# 0         2332  Timehri International airport  JetBlue Airways      HET
#
#                    dt_update
# 0 2024-08-18 13:35:02.945331
#
#    customer_id         aeroporto linha_aerea cod_iata  \
# 0         1375  Jianoiao airport   Air India      PNQ
#
#                    dt_update
# 0 2024-08-18 13:35:02.962753
#
#    customer_id                                         aeroporto  \
# 0          290  General Abelardo L Rodriguez International Airpo
#
#         linha_aerea cod_iata                  dt_update
# 0  Cebu Pacific Air      DSM 2024-08-18 13:35:02.980348
#
#    customer_id                           aeroporto      linha_aerea cod_iata  \
# 0         1876  Hercilio Luz International airport  Alaska Airlines      HFE
#
#                    dt_update
# 0 2024-08-18 13:35:02.998057
#
#    customer_id                    aeroporto       linha_aerea cod_iata  \
# 0         2662  Dubai International airport  Turkish Airlines      CUN
#
#                    dt_update
# 0 2024-08-18 13:35:03.016572
#
#    customer_id                                        aeroporto  \
# 0         1366  Aéroport International Pierre-Elliott-Trudeau d
#
#       linha_aerea cod_iata                  dt_update
# 0  LATAM Airlines      PHX 2024-08-18 13:35:03.034083
#
#    customer_id                        aeroporto     linha_aerea cod_iata  \
# 0         5033  Viru Viru International airport  LATAM Airlines      PHX
#
#                    dt_update
# 0 2024-08-18 13:35:03.051599
#
#    customer_id                         aeroporto  linha_aerea cod_iata  \
# 0          218  Charleston International airport  VietJet Air      JFK
#
#                    dt_update
# 0 2024-08-18 13:35:03.069606
#
#    customer_id                    aeroporto linha_aerea cod_iata  \
# 0         4550  Chubu International airport    Oman Air      SPR
#
#                    dt_update
# 0 2024-08-18 13:35:03.086458
#
#    customer_id         aeroporto       linha_aerea cod_iata  \
# 0         3880  Alicante airport  West Air (China)      MDE
#
#                    dt_update
# 0 2024-08-18 13:35:03.103970
#
#    customer_id                                       aeroporto linha_aerea  \
# 0         6024  Toronto Lester B Pearson International airport     Nam Air
#
#   cod_iata                  dt_update
# 0      SAN 2024-08-18 13:35:03.120485
#
#    customer_id                                 aeroporto    linha_aerea  \
# 0          547  Greater Cincinnati International airport  AirAsia India
#
#   cod_iata                  dt_update
# 0      DUB 2024-08-18 13:35:03.137228
#
#    customer_id aeroporto linha_aerea cod_iata                  dt_update
# 0         3558   Guizhou       GoAir      YNT 2024-08-18 13:35:03.154382
#
#    customer_id                      aeroporto         linha_aerea cod_iata  \
# 0         4737  Tocumen International airport  Southwest Airlines      BKK
#
#                    dt_update
# 0 2024-08-18 13:35:03.171022
#
#    customer_id                         aeroporto         linha_aerea cod_iata  \
# 0         9116  Chongqing Jiangbei International  Southwest Airlines      IQQ
#
#                    dt_update
# 0 2024-08-18 13:35:03.188040
#
#    customer_id           aeroporto      linha_aerea cod_iata  \
# 0         9072  Goiabeiras airport  Maya Island Air      DCA
#
#                    dt_update
# 0 2024-08-18 13:35:03.205550
#
#    customer_id                      aeroporto linha_aerea cod_iata  \
# 0         9670  Kelowna International airport   Batik Air      BNA
#
#                    dt_update
# 0 2024-08-18 13:35:03.222560
#
#    customer_id         aeroporto        linha_aerea cod_iata  \
# 0         8605  Dangriga airport  Malaysia Airlines      ARN
#
#                    dt_update
# 0 2024-08-18 13:35:03.239331
#
#    customer_id                    aeroporto       linha_aerea cod_iata  \
# 0         1238  Dubai International airport  Juneyao Airlines      KJA
#
#                    dt_update
# 0 2024-08-18 13:35:03.257851
#
#    customer_id                              aeroporto linha_aerea cod_iata  \
# 0         5225  King Abdul Aziz International airport  Air Canada      ANF
#
#                    dt_update
# 0 2024-08-18 13:35:03.274859
#
#    customer_id                     aeroporto linha_aerea cod_iata  \
# 0          190  Kansai International airport    Wizz Air      ZRH
#
#                    dt_update
# 0 2024-08-18 13:35:03.293887
#
#    customer_id                                     aeroporto  \
# 0         7565  Alfonso Bonilla Aragon International airport
#
#          linha_aerea cod_iata                  dt_update
# 0  Hawaiian Airlines      CLO 2024-08-18 13:35:03.311834
#
#    customer_id                              aeroporto       linha_aerea  \
# 0         5054  King Abdul Aziz International airport  Juneyao Airlines
#
#   cod_iata                  dt_update
# 0      SAT 2024-08-18 13:35:03.329346
#
#    customer_id                 aeroporto linha_aerea cod_iata  \
# 0         8708  Aeroparque Jorge Newbery       GoAir      SVO
#
#                    dt_update
# 0 2024-08-18 13:35:03.346652
#
#    customer_id                               aeroporto linha_aerea cod_iata  \
# 0         9091  Vienna Schwechat International airport  Tropic Air      SLC
#
#                    dt_update
# 0 2024-08-18 13:35:03.365767
#
#    customer_id                            aeroporto      linha_aerea cod_iata  \
# 0         4180  Gen E L Logan International airport  United Airlines      KZN
#
#                    dt_update
# 0 2024-08-18 13:35:03.384282
#
#    customer_id                        aeroporto      linha_aerea cod_iata  \
# 0         2184  Viru Viru International airport  JetBlue Airways      YNT
#
#                    dt_update
# 0 2024-08-18 13:35:03.402795
#
#    customer_id          aeroporto        linha_aerea cod_iata  \
# 0         1821  Le Raizet airport  Shandong Airlines      TUS
#
#                    dt_update
# 0 2024-08-18 13:35:03.420318
#
#    customer_id          aeroporto      linha_aerea cod_iata  \
# 0         7544  LaGuardia airport  United Airlines      KRR
#
#                    dt_update
# 0 2024-08-18 13:35:03.438838
#
#    customer_id                     aeroporto linha_aerea cod_iata  \
# 0          383  Cataratas del Iguazu airport  Air Canada      BEL
#
#                    dt_update
# 0 2024-08-18 13:35:03.456860
#
#    customer_id             aeroporto      linha_aerea cod_iata  \
# 0         6301  Jorge Chavez airport  Spring Airlines      CNF
#
#                    dt_update
# 0 2024-08-18 13:35:03.474870
#
#    customer_id                          aeroporto               linha_aerea  \
# 0         4709  El Calafate International airport  Southern Airways Express
#
#   cod_iata                  dt_update
# 0      GYE 2024-08-18 13:35:03.494396
#
#    customer_id         aeroporto          linha_aerea cod_iata  \
# 0         9317  Koltsovo airport  Philippine Airlines      NAT
#
#                    dt_update
# 0 2024-08-18 13:35:03.512908
#
#    customer_id           aeroporto       linha_aerea cod_iata  \
# 0         3418  Tolmachevo airport  Chengdu Airlines      CNX
#
#                    dt_update
# 0 2024-08-18 13:35:03.530420
#
#    customer_id                aeroporto         linha_aerea cod_iata  \
# 0         6829  Bergen Flesland airport  Southwest Airlines      JUL
#
#                    dt_update
# 0 2024-08-18 13:35:03.548446
#
#    customer_id              aeroporto       linha_aerea cod_iata  \
# 0         2658  Hefei-Luogang airport  Vietnam Airlines      BOM
#
#                    dt_update
# 0 2024-08-18 13:35:03.567052
#
#    customer_id                         aeroporto            linha_aerea  \
# 0         6662  Pittsburgh International airport  China United Airlines
#
#   cod_iata                  dt_update
# 0      CNX 2024-08-18 13:35:03.586075
#
#    customer_id                      aeroporto linha_aerea cod_iata  \
# 0         5320  Bangkok International airport  Air France      KUL
#
#                    dt_update
# 0 2024-08-18 13:35:03.606085
#
#    customer_id       aeroporto linha_aerea cod_iata                  dt_update
# 0         1043  Lisbon airport  Air Canada      TPA 2024-08-18 13:35:03.623066
#
#    customer_id                    aeroporto      linha_aerea cod_iata  \
# 0         9152  Dubai International airport  British Airways      LED
#
#                    dt_update
# 0 2024-08-18 13:35:03.642073
#
#    customer_id           aeroporto        linha_aerea cod_iata  \
# 0         5935  Paris Orly airport  American Airlines      SJP
#
#                    dt_update
# 0 2024-08-18 13:35:03.659591
#
#    customer_id        aeroporto  linha_aerea cod_iata  \
# 0         5671  Neuquen airport  VietJet Air      DEL
#
#                    dt_update
# 0 2024-08-18 13:35:03.677293
#
#    customer_id             aeroporto  linha_aerea cod_iata  \
# 0          351  Thessaloniki airport  VietJet Air      LPB
#
#                    dt_update
# 0 2024-08-18 13:35:03.695807
#
#    customer_id                                 aeroporto       linha_aerea  \
# 0         3633  Greater Cincinnati International airport  Juneyao Airlines
#
#   cod_iata                  dt_update
# 0      OSL 2024-08-18 13:35:03.713324
#
#    customer_id                               aeroporto       linha_aerea  \
# 0         4369  Bahia Blanca Cte Espora Naval Air Base  Turkish Airlines
#
#   cod_iata                  dt_update
# 0      CPH 2024-08-18 13:35:03.730839
#
#    customer_id                        aeroporto linha_aerea cod_iata  \
# 0         6596  Los Cabos International airport    Lion Air      YYZ
#
#                    dt_update
# 0 2024-08-18 13:35:03.748355
#
#    customer_id                             aeroporto      linha_aerea  \
# 0          608  Tancredo Neves International airport  Spring Airlines
#
#   cod_iata                  dt_update
# 0      YYZ 2024-08-18 13:35:03.766363
#
#    customer_id                                   aeroporto  \
# 0         2681  Gen Mariano Escobedo International airport
#
#                linha_aerea cod_iata                  dt_update
# 0  China Southern Airlines      MDQ 2024-08-18 13:35:03.785060
#
#    customer_id       aeroporto linha_aerea cod_iata                  dt_update
# 0         4935  Geneva airport  Air France      FOC 2024-08-18 13:35:03.804071
#
#    customer_id        aeroporto linha_aerea cod_iata  \
# 0         9759  Otopeni airport       GoAir      CMH
#
#                    dt_update
# 0 2024-08-18 13:35:03.821701
#
#    customer_id       aeroporto linha_aerea cod_iata                  dt_update
# 0         6606  Balice airport   Wings Air      REL 2024-08-18 13:35:03.839339
#
#    customer_id                                aeroporto linha_aerea cod_iata  \
# 0         1210  Lic Benito Juarez International airport    Jeju Air      GOI
#
#                    dt_update
# 0 2024-08-18 13:35:03.857249
#
#    customer_id          aeroporto linha_aerea cod_iata  \
# 0         6053  Sepinggan airport   Lucky Air      STR
#
#                    dt_update
# 0 2024-08-18 13:35:03.875761
#
#    customer_id                     aeroporto      linha_aerea cod_iata  \
# 0         4078  Zurich International airport  Royal Air Maroc      PMV
#
#                    dt_update
# 0 2024-08-18 13:35:03.894770
#
#    customer_id           aeroporto         linha_aerea cod_iata  \
# 0         9923  Paris Orly airport  Southwest Airlines      BPN
#
#                    dt_update
# 0 2024-08-18 13:35:03.913914
#
#    customer_id                           aeroporto linha_aerea cod_iata  \
# 0         1343  Berlin-Tegel International airport  Air France      XIY
#
#                    dt_update
# 0 2024-08-18 13:35:03.933509
#
#    customer_id         aeroporto               linha_aerea cod_iata  \
# 0         1919  Maquehue airport  Southern Airways Express      EWR
#
#                    dt_update
# 0 2024-08-18 13:35:03.953026
#
#    customer_id        aeroporto        linha_aerea cod_iata  \
# 0         8615  Bologna airport  Indonesia AirAsia      KWE
#
#                    dt_update
# 0 2024-08-18 13:35:03.971986
#
#    customer_id                                         aeroporto  \
# 0         5382  Deputado Luis Eduardo Magalhaes International Ai
#
#                 linha_aerea cod_iata                  dt_update
# 0  Southern Airways Express      TPE 2024-08-18 13:35:03.990485
#
#    customer_id                                aeroporto linha_aerea cod_iata  \
# 0          149  Southwest Florida International airport       GoAir      SJD
#
#                    dt_update
# 0 2024-08-18 13:35:04.009489
#
#    customer_id             aeroporto              linha_aerea cod_iata  \
# 0         7528  Nanning-Wuyu airport  China Southern Airlines      MCI
#
#                    dt_update
# 0 2024-08-18 13:35:04.029181
#
#    customer_id                            aeroporto linha_aerea cod_iata  \
# 0         4732  Salgado Filho International airport   Loong Air      KOA
#
#                    dt_update
# 0 2024-08-18 13:35:04.048697
#
#    customer_id                        aeroporto linha_aerea cod_iata  \
# 0         1240  Tribhuvan International airport  Tropic Air      SCL
#
#                    dt_update
# 0 2024-08-18 13:35:04.067622
#
#    customer_id                                aeroporto    linha_aerea  \
# 0         1802  Silvio Pettirossi International airport  AirAsia India
#
#   cod_iata                  dt_update
# 0      HFE 2024-08-18 13:35:04.086367
#
#    customer_id                         aeroporto linha_aerea cod_iata  \
# 0         4743  Chiang Mai International airport   Air China      NNG
#
#                    dt_update
# 0 2024-08-18 13:35:04.105263
#
#    customer_id                                 aeroporto      linha_aerea  \
# 0         1087  Ministro Pistarini International airport  Delta Air Lines
#
#   cod_iata                  dt_update
# 0      CJC 2024-08-18 13:35:04.125292
#
#    customer_id                               aeroporto  \
# 0         6274  General Mitchell International airport
#
#                 linha_aerea cod_iata                  dt_update
# 0  Beijing Capital Airlines      NNG 2024-08-18 13:35:04.144301
#
#    customer_id                      aeroporto       linha_aerea cod_iata  \
# 0         3195  Halifax International airport  Sichuan Airlines      TJA
#
#                    dt_update
# 0 2024-08-18 13:35:04.163351
#
#    customer_id        aeroporto    linha_aerea cod_iata  \
# 0         7302  Palermo airport  Sriwijaya Air      MCZ
#
#                    dt_update
# 0 2024-08-18 13:35:04.182322
#
#    customer_id                        aeroporto      linha_aerea cod_iata  \
# 0         2582  Congonhas International airport  Alaska Airlines      UIO
#
#                    dt_update
# 0 2024-08-18 13:35:04.201840
#
#    customer_id                    aeroporto      linha_aerea cod_iata  \
# 0         8722  Dubai International airport  United Airlines      LIN
#
#                    dt_update
# 0 2024-08-18 13:35:04.219869
#
#    customer_id           aeroporto             linha_aerea cod_iata  \
# 0         2456  Hsien Yang airport  China Eastern Airlines      GEO
#
#                    dt_update
# 0 2024-08-18 13:35:04.238388
#
#    customer_id               aeroporto linha_aerea cod_iata  \
# 0         3062  Capitan Concha airport    Lion Air      ATL
#
#                    dt_update
# 0 2024-08-18 13:35:04.257904
#
#    customer_id                               aeroporto linha_aerea cod_iata  \
# 0         8431  General Mitchell International airport     Nam Air      SEA
#
#                    dt_update
# 0 2024-08-18 13:35:04.274919
#
#    customer_id          aeroporto      linha_aerea cod_iata  \
# 0          746  Le Raizet airport  Royal Air Maroc      FOR
#
#                    dt_update
# 0 2024-08-18 13:35:04.291952
#
#    customer_id            aeroporto linha_aerea cod_iata  \
# 0         9725  Sheremtyevo airport  Air Canada      SGN
#
#                    dt_update
# 0 2024-08-18 13:35:04.308990
#
#    customer_id                          aeroporto linha_aerea cod_iata  \
# 0         1445  El Calafate International airport       GoAir      SXM
#
#                    dt_update
# 0 2024-08-18 13:35:04.327503
#
#    customer_id                       aeroporto       linha_aerea cod_iata  \
# 0         7463  Santarem International airport  Chengdu Airlines      WUX
#
#                    dt_update
# 0 2024-08-18 13:35:04.344513
#
#    customer_id                            aeroporto     linha_aerea cod_iata  \
# 0         4476  Gen E L Logan International airport  LATAM Airlines      AYT
#
#                    dt_update
# 0 2024-08-18 13:35:04.362214
#
#    customer_id           aeroporto       linha_aerea cod_iata  \
# 0         4729  Copenhagen airport  Vietnam Airlines      RSW
#
#                    dt_update
# 0 2024-08-18 13:35:04.380340
#
#    customer_id        aeroporto      linha_aerea cod_iata  \
# 0         1936  Hamburg airport  Spring Airlines      CMH
#
#                    dt_update
# 0 2024-08-18 13:35:04.398349
#
#    customer_id                             aeroporto       linha_aerea  \
# 0         5458  Chicago O'Hare International airport  Vietnam Airlines
#
#   cod_iata                  dt_update
# 0      OSL 2024-08-18 13:35:04.416448
#
#    customer_id        aeroporto      linha_aerea cod_iata  \
# 0         2399  Dabolim airport  Royal Air Maroc      BPN
#
#                    dt_update
# 0 2024-08-18 13:35:04.434838
#
#    customer_id       aeroporto              linha_aerea cod_iata  \
# 0         3324  Malaga airport  China Southern Airlines      MVD
#
#                    dt_update
# 0 2024-08-18 13:35:04.452913
#
#    customer_id                      aeroporto        linha_aerea cod_iata  \
# 0         3935  Memphis International airport  Shandong Airlines      BEG
#
#                    dt_update
# 0 2024-08-18 13:35:04.470238
#
#    customer_id                           aeroporto linha_aerea cod_iata  \
# 0         8206  Teniente Benjamin Matienzo airport     Nok Air      BGY
#
#                    dt_update
# 0 2024-08-18 13:35:04.488269
#
#    customer_id                        aeroporto       linha_aerea cod_iata  \
# 0         8639  Tribhuvan International airport  Juneyao Airlines      HKG
#
#                    dt_update
# 0 2024-08-18 13:35:04.506850
#
#    customer_id              aeroporto          linha_aerea cod_iata  \
# 0         8668  Mar del Plata airport  Philippine Airlines      CCU
#
#                    dt_update
# 0 2024-08-18 13:35:04.525374
#
#    customer_id        aeroporto             linha_aerea cod_iata  \
# 0         6482  Vilnius airport  China Eastern Airlines      SFO
#
#                    dt_update
# 0 2024-08-18 13:35:04.543888
#
#    customer_id             aeroporto       linha_aerea cod_iata  \
# 0         7469  Nanning-Wuyu airport  Sichuan Airlines      TLS
#
#                    dt_update
# 0 2024-08-18 13:35:04.561404
#
#    customer_id           aeroporto            linha_aerea cod_iata  \
# 0         3237  Rebiechowo airport  LOT - Polish Airlines      JDO
#
#                    dt_update
# 0 2024-08-18 13:35:04.578918
#
#    customer_id       aeroporto   linha_aerea cod_iata  \
# 0         4181  Zagreb airport  Thai AirAsia      SGN
#
#                    dt_update
# 0 2024-08-18 13:35:04.598539
#
#    customer_id             aeroporto          linha_aerea cod_iata  \
# 0         4629  Cologne Bonn airport  Philippine Airlines      DAC
#
#                    dt_update
# 0 2024-08-18 13:35:04.618055
#
#    customer_id               aeroporto    linha_aerea cod_iata  \
# 0         9766  Keflavik International  Qatar Airways      CJU
#
#                    dt_update
# 0 2024-08-18 13:35:04.637079
#
#    customer_id                                        aeroporto  \
# 0         5978  Aéroport International Pierre-Elliott-Trudeau d
#
#          linha_aerea cod_iata                  dt_update
# 0  Malaysia Airlines      GOT 2024-08-18 13:35:04.655626
#
#    customer_id          aeroporto        linha_aerea cod_iata  \
# 0          655  Huhehaote airport  Malaysia Airlines      KIX
#
#                    dt_update
# 0 2024-08-18 13:35:04.674637
#
#    customer_id                      aeroporto        linha_aerea cod_iata  \
# 0         6822  El Alto International airport  Hawaiian Airlines      DPS
#
#                    dt_update
# 0 2024-08-18 13:35:04.693979
#
#    customer_id                           aeroporto       linha_aerea cod_iata  \
# 0          590  Hercilio Luz International airport  Tianjin Airlines      SKG
#
#                    dt_update
# 0 2024-08-18 13:35:04.712517
#
#    customer_id           aeroporto      linha_aerea cod_iata  \
# 0         4326  Paris Orly airport  Alaska Airlines      MDW
#
#                    dt_update
# 0 2024-08-18 13:35:04.732034
#
#    customer_id                         aeroporto               linha_aerea  \
# 0         2232  Dusseldorf International airport  Southern Airways Express
#
#   cod_iata                  dt_update
# 0      BGY 2024-08-18 13:35:04.751546
#
#    customer_id     aeroporto             linha_aerea cod_iata  \
# 0         5780  Shijiazhuang  China Eastern Airlines      STM
#
#                    dt_update
# 0 2024-08-18 13:35:04.769556
#
#    customer_id        aeroporto linha_aerea cod_iata  \
# 0         7598  Lanzhou airport   Wings Air      BHX
#
#                    dt_update
# 0 2024-08-18 13:35:04.787282
#
#    customer_id                            aeroporto      linha_aerea cod_iata  \
# 0          363  Nanjing Lukou International airport  Spirit Airlines      MSP
#
#                    dt_update
# 0 2024-08-18 13:35:04.803800
#
#    customer_id                 aeroporto        linha_aerea cod_iata  \
# 0         6011  Nice-Cote d'Azur airport  Shenzhen Airlines      CMH
#
#                    dt_update
# 0 2024-08-18 13:35:04.822001
#
#    customer_id aeroporto linha_aerea cod_iata                  dt_update
# 0         3946    Belize   Batik Air      HYD 2024-08-18 13:35:04.839583
#
#    customer_id                 aeroporto    linha_aerea cod_iata  \
# 0         6625  Sesquicentenario airport  Ural Airlines      TPP
#
#                    dt_update
# 0 2024-08-18 13:35:04.857098
#
#    customer_id aeroporto        linha_aerea cod_iata  \
# 0         4203   Guizhou  Shandong Airlines      BUR
#
#                    dt_update
# 0 2024-08-18 13:35:04.876107
#
#    customer_id        aeroporto linha_aerea cod_iata  \
# 0         9305  Antalya airport   Loong Air      JJN
#
#                    dt_update
# 0 2024-08-18 13:35:04.895159
#
#    customer_id        aeroporto linha_aerea cod_iata  \
# 0          196  Vilnius airport  Air France      MEX
#
#                    dt_update
# 0 2024-08-18 13:35:04.913179
#
#    customer_id            aeroporto    linha_aerea cod_iata  \
# 0         9852  Sheremtyevo airport  Qatar Airways      LHR
#
#                    dt_update
# 0 2024-08-18 13:35:04.931691
#
#    customer_id                        aeroporto      linha_aerea cod_iata  \
# 0          732  General Enrique Mosconi airport  Alaska Airlines      LYS
#
#                    dt_update
# 0 2024-08-18 13:35:04.949203
#
#    customer_id         aeroporto       linha_aerea cod_iata  \
# 0          921  Begumpet airport  Skymark Airlines      PVR
#
#                    dt_update
# 0 2024-08-18 13:35:04.967211
#
#    customer_id                         aeroporto linha_aerea cod_iata  \
# 0         4114  Del Caribe International airport       GoAir      CSX
#
#                    dt_update
# 0 2024-08-18 13:35:04.984737
#
#    customer_id                                        aeroporto  \
# 0         7367  Aéroport International Pierre-Elliott-Trudeau d
#
#        linha_aerea cod_iata                  dt_update
# 0  British Airways      MKE 2024-08-18 13:35:05.004249
#
#    customer_id                             aeroporto       linha_aerea  \
# 0         1557  Chicago Midway International airport  Tianjin Airlines
#
#   cod_iata                  dt_update
# 0      HYD 2024-08-18 13:35:05.021854
#
#    customer_id           aeroporto            linha_aerea cod_iata  \
# 0         4937  Las Palmas airport  LOT - Polish Airlines      PCL
#
#                    dt_update
# 0 2024-08-18 13:35:05.039371
#
#    customer_id        aeroporto linha_aerea cod_iata  \
# 0         6644  Otopeni airport   Batik Air      KWE
#
#                    dt_update
# 0 2024-08-18 13:35:05.057401
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 54
#      51 if not args.silent:
#      52     print(df, end="\n\n")
# ---> 54 time.sleep(args.interval)
#
# KeyboardInterrupt:
